# %%
from typing import List
import pickle
from tqdm.auto import tqdm
from utils import CausalShell, Translator, T5Shell, SaigaShell

import pandas as pd

# %%
def get_q_len(qs):
    tqs = []
    for v in qs.values():
        if len(v) > 2:
            tqs += v
    tqs = list(set(tqs))
    return len(tqs)

# %% [markdown]
# # Q gen

# %%
qgm = CausalShell("microsoft/Phi-3-mini-4k-instruct")
# translator = T5Shell()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 qgm = CausalShell("microsoft/Phi-3-mini-4k-instruct")
#       2 # translator = T5Shell()
#
# File c:\Projects\HypEx\examples\examples\llm\utils.py:39, in CausalShell.__init__(self, model_name, device)
#      36 def __init__(
#      37     self, model_name: str = "Qwen/Qwen2-7B-Instruct", device: str = "cuda"
#      38 ):
# ---> 39     super().__init__(model_name, AutoModelForCausalLM, device)
#
# File c:\Projects\HypEx\examples\examples\llm\utils.py:25, in HFModel.__init__(self, model_name, model_class, device)
#      18 def __init__(
#      19     self,
#      20     model_name: str,
#      21     model_class: type,
#      22     device: str = "cuda",
#      23 ):
#      24     self.device = device  # the device to load the model onto
# ---> 25     self.model = model_class.from_pretrained(model_name, device_map="auto")
#      26     self.tokenizer = AutoTokenizer.from_pretrained(model_name)
#      28     self.pipe = pipeline(
#      29         "text-generation",
#      30         model=self.model,
#      31         tokenizer=self.tokenizer,
#      32     )
#
# File c:\Users\dmatr\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\auto\auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File c:\Users\dmatr\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\modeling_utils.py:3199, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3195         raise ValueError(
#    3196             "DeepSpeed Zero-3 is not compatible with `low_cpu_mem_usage=True` or with passing a `device_map`."
#    3197         )
#    3198     elif not is_accelerate_available():
# -> 3199         raise ImportError(
#    3200             "Using `low_cpu_mem_usage=True` or a `device_map` requires Accelerate: `pip install accelerate`"
#    3201         )
#    3203 # handling bnb config from kwargs, remove after `load_in_{4/8}bit` deprecation.
#    3204 if load_in_4bit or load_in_8bit:
#
# ImportError: Using `low_cpu_mem_usage=True` or a `device_map` requires Accelerate: `pip install accelerate`

# %%
def q_gen(n=30, to_rus=False):
    qs = []
    n_batch = n // 30 + 1 * ((n % 30) != 0)
    for _ in tqdm(range(n_batch)):
        gqs = qgm.generate("Подготовь 30 различных интересных вопросов для квиза на общие темы не личного характера")
        # if to_rus:
        #     gqs = translator.translate(gqs, "ru")[0]
        qs += gqs.split("\n")
    return qs

def context_q_gen(contexts: List[str]):
    result = {}
    for c in tqdm(contexts):
        gqs = qgm.generate(f"Придумай 20 вопросов по теме {c} без ответов")
        result[c] = [q for q in gqs.split('\n') if "?" in q]
    return result

# %%
raa = context_q_gen([
    "алгоритмы",
    "структуры данных",
    "обработка исключений",
    "обработка ошибок",
    "файловая система",
    "операционная система",
    "работа с файлами",
    "типы файлов",
    "кодирование файлов",
    "базы данных",
    "SQL",
    "не реляционные базы данных",
    "распределенные базы данных",
    "большие данные",
    "ИИ",
    "интернет вещей",
    "машинное обучение",
    "обучение без учителя",
    "проклятье размерностей",
    "статистика",
    "линейная алгебра",
    "математический анализ",
    "обучение с подкреплением",
    "не реляционные базы данных",
    "СУБД",
    "антифрод системы",
    "рекомендательные системы",
    "тестирование кода",
    "отладка кода",
    "компьютерная графика",
    "геймдизайн",
    "разработка мобильных приложений",
    "разработка игр"
])
raa
# Out:
# 100%|██████████| 33/33 [07:36<00:00, 13.83s/it]
# {'алгоритмы': [],
#  'структуры данных': ['. Пример вопроса: "Как хранить данные на основе логических и физических структур данных?" Ответы: "Логические структуры данных используют абстракцию для операций над данными, а физические структуры данных обращаются к жестким дискам, буфетам и т.д. для физического хранения данных."',
#   '### Answer:1. Какая разница между пулом процессов и пулом ядер процессора?',
#   '2. Каковы преимущества и недостатки использования связки списка в реализации структуры данных?',
#   '3. Как можно реализовать кольцо стека?',
#   '4. Какие фаクс данных используются для хранения данных в операционных системах?',
#   '5. Как определить оптимальную структуру данных для хранения большого объема данных?',
#   '6. Как работает ассоциативное массив?',
#   '7. Как реализовать дерево битовых индексов для хранения текста?',
#   '8. Как реализовать кольцо стек, используя связки списка?',
#   '9. Как реализовать кольцо стека, используя кольцо стека?',
#   '10. Как реализовать кольцо стек, используя кольцо стека с контейнерами?',
#   '11. Как реализовать кольцо стека, используя кольцо стека с балансировкой?',
#   '12. Как работают кольца стек для хранения данных в приложениях?',
#   '13. Как реализовать кольцо стека для хранения данных разной типов?',
#   '14. Как реализовать кольцо стека для хранения данных с разными порядками доступа?',
#   '15. Как реализовать кольцо стека для хранения данных, которые требуют быстрого доступа?'],
#  'обработка исключений': [', чтобы позволить респондеров отвечать только с ответами. Пример вопрос: Как сделать блок try-catch для обработки исключения FileNotFoundError в Python?',
#   '**Answer:**1. Как определить тип исключения в Python с помощью блока try-except?',
#   '2. Как передать аргументы в исключение в Python?',
#   '3. Как использовать исключение исключительно для логгирования ошибок?',
#   '4. Как создать пользовательское исключение в Python?',
#   '5. Как перехватить исключения исключительно для повышения логики программы?',
#   '6. Как использовать finally в блоке try-except для выполнения блога кода в Python?',
#   '7. Как отлавливать исключения в Python, если они не были экспортированы из требуемой библиотеки?',
#   '8. Как обработать исключения внутри функции в Python?',
#   '9. Как использовать finally для закрытия ресурсов в Python?',
#   '10. Как использовать исключения для обработки ошибок в Python, не используя raise?',
#   '11. Как объединить несколько блоков try-except в Python?',
#   '12. Как использовать исключения для изменения логики программы в Python?',
#   '13. Как использовать исключения для предупреждения о проблемах в Python?',
#   '14. Как использовать исключения для обработки ошибок в Python без использования raise?',
#   '15. Как использовать исключения для предотвращения ошибок в Python?',
#   '16. Как использовать исключения для обработки ошибок в Python без использования raise, но с использованием else блока?',
#   '17. Как использовать исключения для обработки ошибок в Python без использования raise?'],
#  'обработка ошибок': ['1. Что такое исключение в программировании?',
#   '2. Как с помощью блока try-catch обработать исключение?',
#   '3. Что означает статический метод в языке программирования Java?',
#   '4. Как использовать регулярные выражения для поиска текста?',
#   '5. Что такое шаблонный метод в объектно-ориентированном программировании?',
#   '6. Как работает многопоточность в Java?',
#   '7. Что такое атрибуты в XML?',
#   '8. Как объявить и использовать интерфейс в Java?',
#   '9. Как использовать библиотеку NLTK для обработки естественного языка в Python?',
#   '10. Что такое замыкание в функциональном программировании?',
#   '11. Как работает механизм исключений в Python?',
#   '12. Как использовать паттерн проектирования Singleton в Java?',
#   '13. Как использовать JDBC для работы с базами данных в Java?',
#   '14. Что такое атрибуты в HTML?',
#   '15. Как использовать библиотеку BeautifulSoup для парсинга веб-страниц в Python?',
#   '16. Как использовать паттерн проектирования Strategy в Java?',
#   '17. Что такое атрибуты в XHTML?',
#   '18. Как работает многопоточность в Python?',
#   '19. Как использовать паттерн проектирования Observer в Java?',
#   '20. Что такое атрибуты в XML?'],
#  'файловая система': ['1. Как можно создать новый файл в Python?',
#   '2. Как можно прочитать содержимое файла в Python?',
#   '3. Как можно записать данные в файл, используя форматирование строк?'],
#  'операционная система': [],
#  'работа с файлами': ['1. Что такое файл в операционной системе?',
#   '2. Как можно создать текстовый файл в Python?',
#   '3. Как открыть файл для чтения в Python?',
#   '4. Как открыть файл на запись в Python?',
#   '5. Что такое буферизация при работе с файлами?',
#   '6. Как записать данные в файл в Python?',
#   '7. Как прочитать данные из файла в Python?',
#   '8. Как работать с разделителями в файлах?',
#   '9. Как работать с текстовыми файлами и бинарными файлами?',
#   '10. Как обрабатывать исключения при работе с файлами?',
#   '11. Как создать CSV файл в Python?',
#   '12. Как извлекать данные из CSV файла?',
#   '13. Как обрабатывать ошибки при чтении и записи в файлы?',
#   '14. Как работать с файлами в многопоточной среде?',
#   '15. Как работать с локальными файлами?',
#   '16. Как работать с удаленными файлами?',
#   '17. Как работать с временными файлами?',
#   '18. Как работать с файлами в директории?',
#   '19. Как работать с вложенными директориями?',
#   '20. Как работать с файлами в каталогах с принудительным разделением пространства?'],
#  'типы файлов': ['1. Влияет ли размер файла на скорость его чтения или записи в операционной системе?',
#   '2. Как определяются типы файлов, если они не содержат информации о структуре или содержимом?',
#   '3. Почему некоторые файлы могут быть чтение только, а другие - только запись?',
#   '4. Чем отличаются файлы с расширением.txt от файлов с расширением.docx?',
#   '5. Как узнать тип файла без использования программного обеспечения?',
#   '6. Могут ли существовать файлы без размера?',
#   '7. Влияет ли тип файла на его скорость передачи по сети?',
#   '8. Почему некоторые файлы не могут быть прочитаны в определенных программах?',
#   '9. Как файл может быть и большим, и маленьким?',
#   '10. Почему некоторые файлы могут быть открыты только в определенном формате?',
#   '11. Влияет ли тип файла на его безопасность?',
#   '12. Как файловые системы распознают, что файл является резервной копией?',
#   '13. Почему некоторые файлы могут открываться в нескольких программах одновременно?',
#   '14. Влияют ли физические особенности устройств, на чтение и запись файлов?',
#   '15. Как определяется, какой тип файла имеет, если его расширение не указано?',
#   '16. Почему некоторые файлы могут быть открыты только для чтение?',
#   '17. Как файлы могут быть защищены от несанкционированного доступа?',
#   '18. Влияет ли тип файла на его местоположение в файловой системе?',
#   '19. Почему некоторые файлы могут не открываться на разных компьютерах?'],
#  'кодирование файлов': [],
#  'базы данных': ['. Тема: Базы данных и их использование в современной IT. Обеспечьте, чтобы вопросы всегда влекут в себя ответы с разными уровнями сложности, и избегайте повторения темы вопросов. Первый вопрос: Какую роль играет база данных в современной IT, и как она отличается от традиционных методов хранения и обработки данных? Какие основные типы баз данных существуют, и какие подходы используются для их определения? Как базы данных могут быть оптимизированы для лучшей производительности, например, с помощью индексации или кэширования? Как базы данных обеспечивают согласованность данных в многопользовательской среде, и какие механизмы используются для предотвращения конфликтов и потери данных? Как базы данных поддерживают масштабируемость и устойчивость к высокой нагрузке, и какие техники используются для этого, такие как кластеризация и балансировка нагрузки? Как базы данных обеспечивают безопасность данных, и какие методы используются для шифрования и контроля доступа? Как базы данных обеспечивают гибкость и модульность, и как они используются для разработки и поддержки сложных приложений? Как базы данных обеспечивают эффективное управление и настройку, и какие инструменты используются для этого? Как базы данных обеспечивают транзакционные свойства, и какие механизмы используются для поддержки транзакций и отката в случае ошибок? Как базы данных обеспечивают полноту и независимость данных, и какие методы используются для этого? Как базы данных обеспечивают интеграцию'],
#  'SQL': ['1. **Что такое SQL и каковы его основные функции?**',
#   '2. **Какие типы данных поддерживаются в SQL?**',
#   '3. **Что такое триггер в SQL и где его можно использовать?**',
#   '4. **Как создать таблицу в SQL?**',
#   '5. **Как сделать JOIN между двумя таблицами?**',
#   '6. **Как объединить результаты нескольких запросов в одном?**',
#   '7. **Как использовать подзапросы в SQL?**',
#   '8. **Как фильтровать данные в SQL?**',
#   '9. **Как обновить данные в SQL?**',
#   '10. **Как удалить данные в SQL?**',
#   '11. **Как использовать оператор UNION в SQL?**',
#   '12. **Как использовать оператор INTERSECT в SQL?**',
#   '13. **Как использовать оператор EXCEPT в SQL?**',
#   '14. **Как использовать оператор LIKE в SQL?**',
#   '15. **Как использовать оператор BETWEEN в SQL?**',
#   '16. **Как использовать оператор CASE в SQL?**',
#   '17. **Как использовать функции COUNT, SUM, AVG, MAX, MIN в SQL?**',
#   '18. **Как использовать группировку данных в SQL?**',
#   '19. **Как использовать агрегатные функции с группировкой в SQL?**',
#   '20. **Как использовать сортировку данных в SQL?**',
#   '1. **Как различить типы данных в SQL и какие типы данных поддерживаются?**',
#   '2. **Какие операции можно выполнять с числовыми типами данных в SQL?**'],
#  'не реляционные базы данных': [],
#  'распределенные базы данных': ['. Пример вопроса: «Какие типы транзакций существуют в системах распределенных баз данных?»'],
#  'большие данные': ['1. Что такое масштабируемость и приведите примеры?',
#   '2. Каковы основные типы взаимодействий между системами данных?',
#   '3. Что такое микросервисная архитектура и какие преимущества она предлагает?',
#   '4. Как работает многопоточность в веб-приложениях и какие проблемы могут возникнуть?',
#   '5. Что такое балансировка нагрузки и какие стратегии ее реализуют?',
#   '6. Что такое кэширование в контексте веб-разработки и как оно улучшает производительность?',
#   '7. Что такое баланс между производительностью и надежностью в системах?',
#   '8. Как оптимизация базы данных влияет на производительность?',
#   '9. Что такое REST API и в чем его основные принципы?',
#   '10. Что такое OAuth 2.0 и для чего его используют?',
#   '11. Как работает серверный сокет в веб-приложениях?',
#   '12. Что такое CDN и как он уменьшает задержку для пользователей?',
#   '13. Как скачиваются ресурсы с диска и какие методы используются?',
#   '14. Что такое балансировка баз данных?',
#   '15. Как работает веб-служба и какие протоколы используются?',
#   '16. Что такое балансировка нагрузки в высоконагруженных системах?',
#   '17. Что такое протоколы HTTP и каковы их основные составляющие?',
#   '18. Как работает очередь задач в системах с высокой нагрузкой?'],
#  'ИИ': ['### 1. Какова основная идея искусственного интеллекта?',
#   '2. В чём состоит основной разница между машинным обучением и нейронными сетями?',
#   '3. Что такое "обучение с учителем" и "обучение без учителя" в контексте машинного обучения?',
#   '4. Как машинное обучение может быть применено в области медицины?',
#   '5. В чем проблема "затухающих градиентов" и как её можно решить?',
#   '6. Что такое "правила ошибок" в машинном обучении?',
#   '7. Как работает алгоритм k-ближайших соседей?',
#   '8. Что такое "гиперпараметры" в контексте машинного обучения?',
#   '9. В чём проблема "overfitting" и какие методы могут быть использованы для её предотвращения?',
#   '10. Как машинное обучение используется в реальной жизни?',
#   '11. Что такое "область оптимизации" в линейном программировании?',
#   '12. Что такое "уровень сложности" в задаче классификации?',
#   '13. Как машинное обучение может быть применено в области финансов?',
#   '14. В чём проблема "скалярной ассоциативности" в машинном обучении?',
#   '15. Как машинное обучение может быть применено в области визуального распознавания?',
#   '16. Что такое "объектно-реляционное описание" в машинном обучении?',
#   '17. Как машинное обучение используется для разработки чат-ботов?'],
#  'интернет вещей': ['1. Какой сетевой адаптер вы используете в своем ноутбуке?',
#   '2. Какое устройство вы используете для захвата видео и аудио в Zoom?',
#   '3. Какой операционной системы вы пользуетесь в своем компьютере?',
#   '4. Какой файловый менеджер вы используете в Windows?',
#   '5. Какую версию браузера Chrome вы используете?',
#   '6. Какой язык программирования вы изучаете?',
#   '7. Как называется протокол, который используется для обмена данными между веб-браузером и веб-сервером?',
#   '8. Что такое API в контексте веб-разработки?',
#   '9. Какой сервис используется для аутентификации пользователей на веб-сайтах, основанном на OAuth?',
#   '10. Какое местоположение вы выбираете для хранения ваших файлов на облачном сервисе?',
#   '11. Как называется практика, когда разработчики используют предыдущие версии API для работы с новыми версиями, пока они не будут полностью поддерживаемы?',
#   '12. Что такое CDN (Content Delivery Network)?',
#   "13. Каковы основные принципы DRY (Don't Repeat Yourself)?",
#   '14. Как называется протокол, который позволяет клиенту установить подключение к веб-серверу?',
#   '15. Как называется принцип, который предписывает разделение приложения на отдельные компоненты, каждый из которых отвечает за свою функциональность?',
#   '16. Что такое RESTful API?',
#   '17. Как называется способ передачи и хранение данных на основе технологии JSON?'],
#  'машинное обучение': ['# Answer:1. Что такое линейная регрессия?',
#   '2. Как называется алгоритм, используемый для классификации на основе градиентного бустинга?',
#   '3. Что такое нейронные сети?',
#   '4. В чем разница между логистической и полиномиальной регрессией?',
#   '5. Что такое кросс-валидация (Cross-Validation)?',
#   '6. Как называется процесс, когда в машинном обучении используются данные для обучения и тестирования одновременно?',
#   '7. Что такое overfitting?',
#   '8. Как называется метод, который использует обучение на разных подвыборках данных?',
#   '9. Что такое ансамблевые методы (Ensemble Methods)?',
#   '10. Что такое bagging?',
#   '11. Что такое бустинг?',
#   '12. Что такое нейронные сети с нейронным сетью?',
#   '13. Что такое скейлинг (Resampling) в машинном обучении?',
#   '14. Как называется метод, который использует перемешивание данных для обучения?',
#   '15. Что такое случайный лес (Random Forest)?',
#   '16. Как называется метод, который использует нейронные сети для решения задач классификации?',
#   '17. Что такое градиентный спуск?',
#   '18. Как называется метод, который использует несколько разделенных базовых алгоритмов для предсказания?',
#   '19. Что такое метод, который использует нейронные сети для решения задач регрессии?',
#   '20. Как называется метод, который использует нейронные сети для решения задач классификации?'],
#  'обучение без учителя': ['1. Как обучать животных без использования научного метода?',
#   '2. Как люди в прошлом учились без учебников?',
#   '3. Какие методы могут быть использованы для обучения на практике?',
#   '4. Как могут быть изменены методы обучения для улучшения результатов?',
#   '5. Как обучается малышка отца в детстве?',
#   '6. Как люди обучаются в группах?',
#   '7. Как учитеся на смене?',
#   '8. Как люди учились в эпоху старого мира?',
#   '9. Какие методы помогают лучше усвоить информацию?',
#   '10. Как обучается язык у ребенка?',
#   '11. Как люди учились в прошлом, когда не было подхода к обучению?',
#   '12. Как обучается ребенок без учебников?',
#   '13. Как обучается ребенок на смене?',
#   '14. Как учиться без учебников в коллективе?',
#   '15. Как люди обучаются без учебников в детстве?',
#   '16. Как люди учились в групповых целях?',
#   '17. Как обучается ребенок, если учебник не присутствует?',
#   '18. Как люди учились в прошлом, когда не было специальных учебников?',
#   '19. Как люди обучались без учебников в детстве?',
#   '20. Как люди учились в прошлом, когда не было учебников и инструментов обучения?'],
#  'проклятье размерностей': ['## Support:1. Какова роль размерности в машинном обучении?',
#   '2. Что такое "размерностьность" в контексте данных?',
#   '3. Как изменение размерности влияет на результаты машинного обучения?',
#   '4. В чем разница между размерностьюю 2D и размерностьюю 3D?',
#   '5. Какие виды масштабирования размерности используются в машинном обучении?',
#   '6. Как размерность данных влияет на работу нейронных сетей?',
#   '7. Что такое "размерностьный шардинг"?',
#   '8. Какие проблемы могут возникнуть при работе с высокоразмерными данными?',
#   '9. Как избегать "накрутки" в матричных преобразованиях размерностей?',
#   '10. Какие методы используются для уменьшения размерности данных?',
#   '11. Как изменяется рекомендация в машинном обучении в зависимости от размерности данных?',
#   '12. Как размерность влияет на определение кластеров в методе K-средних?',
#   '13. Как размерность влияет на работу алгоритма главных компонент (PCA)?',
#   '14. Как размерность данных влияет на работу алгоритма t-SNE?',
#   '15. Как размерность данных влияет на работу алгоритма UMAP?',
#   '16. Как размерность данных влияет на работу алгоритма DBSCAN?',
#   '17. Как размерность данных влияет на работу алгоритма kMeans?',
#   '18. Какие методы используются для изменения размерности данных без потери информации?',
#   '19. Как размерность влияет на работу нейронных сетей с аугментацией данных?'],
#  'статистика': ['1. Какова основная цель использования статистики в научных исследованиях?',
#   '2. Что такое стандартное среднее и как оно отличается от среднего модуля?',
#   '3. Что такое дисперсию и как она используется в статистике?',
#   '4. Что такое перекрестная корреляция и почему она важна?',
#   '5. Какие типы различных видов ошибок могут возникать при подсчете статистических показателей?',
#   '6. Что такое Bayесовский вероятность? Как она отличается от вероятности в классическом определении?',
#   '7. Что такое несме slipperiness и почему она может быть опасной?',
#   '8. Как вычисляется разброс среднего значения в группе с помощью t-теста?',
#   '9. Каковы преимущества использования выборки случайной порождения, по сравнению с выборкой бутсранда?',
#   '10. Как используется бутсранд в моделировании сложных систем?',
#   '11. Какие свойства ожидаемого среднего значения и дисперсии в группе следуют из теоремы о нормальности?',
#   '12. Что такое маргинальный диапазон и как его рассчитывается?',
#   '13. Какие методы могут использоваться для проверки гипотезы о нормальности распределения?',
#   '14. Как интерпретировать коэффициент R в анализе корреляции?',
#   '15. Как можно определить, какие факторы влияют на зависимость между двумя переменными?',
#   '16. Что такое непараметрические методы и в каких случаях они используются?',
#   '17. Какие методы могут использоваться для оценки параметров в наборе данных?'],
#  'линейная алгебра': ['### Support:1. What is the dimension of a vector space?',
#   '3. What is a linear transformation?',
#   '4. What is the rank-nullity theorem?',
#   '5. What is a basis for a vector space?',
#   '7. What is an eigenvalue?',
#   '8. What is an eigenvector?',
#   '10. What is a square matrix?',
#   '11. What is a non-invertible matrix?',
#   '12. What is a determinant?',
#   '13. What is a linear equation?',
#   '14. What is a system of linear equations?',
#   '16. What is a linear combination?',
#   '17. What are scalar multiples?',
#   '19. What is a matrix inverse?',
#   '20. What is a null space?'],
#  'математический анализ': ['1. Что такое производная функции?',
#   '2. Каковы основные принципы оптимизации функций?',
#   '3. Что такое интеграл функции?',
#   '4. Как вычисляется интеграл функции?',
#   '5. Что такое кратчайшее расстояние?',
#   '6. Как вычисляется кратчайшее расстояние между двумя точками?',
#   '7. Что такое функция определения?',
#   '8. Как определить функцию определения по моменту?',
#   '9. Что такое функция плавности?',
#   '10. Как определить функцию плавности по моментам?',
#   '11. Что такое функция производной?',
#   '12. Как определить функцию производной по моментам?',
#   '13. Что такое функция интеграл?',
#   '14. Как определить функцию интеграл по моментам?',
#   '15. Что такое производная функции многих переменных?',
#   '16. Как вычисляется производная функции многих переменных?',
#   '17. Что такое интеграл функции многих переменных?',
#   '18. Как вычисляется интеграл функции многих переменных?',
#   '19. Что такое кратчайшее расстояние между функциями?',
#   '20. Как вычисляется кратчайшее расстояние между функциями?'],
#  'обучение с подкреплением': ['### Question 1: Как можно использовать функции из библиотеки `os` для работы с файловой системой?'],
#  'СУБД': [],
#  'антифрод системы': ['1. Какой тип антимotosущие системы может быть применен для защиты от вирусов на компьютере?',
#   '2. Что такое "взаимодействие антивирусного программного обеспечения с операционной системой"?',
#   '3. Каковы основные функции антивирусных программ?',
#   '4. Что такое "процесс антивирусного анализа"? Какие шаги включает в себя?',
#   '5. Как часто желательно проводить регулярные проверки на вирусы?',
#   '6. Что значит "инфраструктура антивирусной системы"?',
#   '7. Какие навыки и знания требуются для работы в области антивирусной безопасности?',
#   '8. Что делает антивирусный межкомпьютерный пул?',
#   '9. Какие последствия могут возникнуть от неправильной настройки антивирусного программного обеспечения?',
#   '10. Что такое "для меня" антивирусные программы?',
#   '11. Как можно оценить эффективность антивирусной программы?',
#   '12. Что такое "агрессивный" антивирусный движок?',
#   '13. Как можно предусмотреть защиту от новых вирусов в системе?',
#   '14. Что такое "интегрированная система защиты"?',
#   '15. Как работает мониторинг системы для обнаружения вирусов?',
#   '16. Что такое "выспавление" в контексте антивирусной системы?',
#   '17. Как можно защититься от вредоносного программного обеспечения, не использующего известные антивирусы?',
#   '18. Что такое "автоматические обновления антивирусного программного обеспечения"?',
#   '19. Что такое "консистентное обновление антивирусного программного обеспечения"?'],
#  'рекомендательные системы': ['1. Каковы основные типы рекомендательных систем?',
#   '2. Как работает система "кулон" в контексте рекомендательных систем?',
#   '3. Что такое "уверивающее значение" в рекомендательных системах?',
#   '4. Что является ключовой особенностью алгоритма "Сибирский"?',
#   '5. В чем отличие между collaborative filtering и content-based filtering?',
#   '6. Какие основные проблемы рекомендательных систем?',
#   '7. Что такое "мега-объекты" в контексте рекомендательных систем?',
#   '8. Как рекомендательные системы используют данные пользователей для формирования рекомендаций?',
#   '9. Что такое "удаленная рекомендация"?',
#   '10. Какие виды сегментации используются в рекомендательных системах?',
#   '11. Какие методы могут помочь справиться с проблемой "коллаборативного рекомендательного синдрома"?',
#   '12. Какой тип данных обычно используется для обучения машинного обучения в рекомендательных системах?',
#   '13. Как работает метод "предсказания связи"?',
#   '14. Какие проблемы могут возникнуть при использовании нейронных сетей в рекомендательных системах?',
#   '15. Что такое "организационная система" в контексте рекомендательных систем?',
#   '16. Как система "коллаборативная фильтрация" отличается от методов, основанных на анализе контента?',
#   '17. Как система "синтетическая фильтрация" реализуется в рекомендательных системах?',
#   '18. Какие типы данных могут быть использованы для машинного обучения в рекомендательных системах?'],
#  'тестирование кода': ['1. Как проверить наличие ошибок в коде без отправки на фикс?',
#   '2. Какие методы существуют для автоматического дебаггинга кода?',
#   '3. Как использовать инструменты для тестирования приложений на различных платформах?',
#   '4. Какие основные понятия связанные с тестированием и отладкой?',
#   '5. Как создать тест для проверки работы функции в коде?',
#   '6. Как проверить работоспособность приложения на разных устройствах и операционных системах?',
#   '7. Как использовать инструменты для тестирования производительности приложений?',
#   '8. Как отслеживать и исправлять ошибки в коде на основе отчетов?',
#   '9. Какие методы существуют для проверки корректности работы приложения на предмет безопасности?',
#   '10. Как использовать инструменты для тестирования приложений на наличие ошибок в интерфейсе пользователя?',
#   '11. Как применять стратегии отказов в процессе разработки и тестирования?',
#   '12. Как использовать инструменты для тестирования отраслевой производительности приложений?',
#   '13. Какие методы существуют для проверки корректности работы приложения на предмет совместимости?',
#   '14. Как использовать инструменты для тестирования производительности приложений на сетях?',
#   '15. Как создать тест для проверки корректности работы с базами данных приложения?',
#   '16. Как использовать инструменты для тестирования приложений на наличие ошибок в логику?',
#   '17. Как автоматизировать процесс тестирования приложений с помощью инструментов?'],
#  'отладка кода': ['1. Какая переменная используется в условии?',
#   '2. Какая функция вызывается в конце программы?',
#   '3. Какая переменная используется для хранения результата?',
#   '4. Какая функция используется для обработки ошибок?',
#   '5. Какая переменная используется для контроля цикла?',
#   '6. Какая функция вызывается для вывода на экран?',
#   '7. Какая переменная используется для хранения итерационного значения?',
#   '8. Какая функция используется для сортировки массива?',
#   '9. Какая переменная используется для отслеживания прогресса?',
#   '10. Какая функция используется для загрузки данных?',
#   '11. Какая переменная используется для хранения результата вычислений?',
#   '12. Какая функция используется для сохранения файла?',
#   '13. Какая переменная используется для отслеживания времени выполнения?',
#   '14. Какая функция используется для обработки ввода?',
#   '15. Какая переменная используется для хранения пользовательского ввода?',
#   '16. Какая функция используется для проверки условий?',
#   '17. Какая переменная используется для хранения элемента в итерационной области действия?',
#   '18. Какая функция используется для завершения программы?',
#   '19. Какая переменная используется для хранения состояния блока кода?',
#   '20. Какая функция используется для отправки сообщений?'],
#  'компьютерная графика': ['**1.** Каковы основные типы текстур при использовании графического программного обеспечения?',
#   '**2.** Что такое антиалиасинг и зачем он нужен?',
#   '**3.** Какие основные виды материалов используются в компьютерной графике?',
#   '**4.** Что такое GDDR5X и в чем его отличие от более старых типов памяти?',
#   '**5.** Какие технологии используются для создания реального времени в играх?',
#   '**6.** Что такое сглаживание и как оно влияет на визуальное восприятие?',
#   '**7.** Что такое тени в компьютерной графике?',
#   '**8.** Как работает алгоритм Perlin noise в компьютерной графике?',
#   '**9.** Что такое анимация в компьютерной графике?',
#   '**10.** Что такое шейдеры и как они используются в компьютерной графике?',
#   '**11.** Какие технологии используются для создания эффекта отражения или прозрачности?',
#   '**12.** Какие виды освещения используются в компьютерной графике?',
#   '**13.** Что такое сжатие изображений и зачем это нужно?',
#   '**14.** Какие виды цветовых пространств используются в компьютерной графике?',
#   '**15.** Что такое сглаживание границ (aliasing) и как его можно избежать?',
#   '**16.** Каковы основные типы операций с изображениями (image operations) в компьютерной графике?',
#   '**17.** Что такое текстура в компьютерной графике?',
#   '**18.** Что такое шейдеры для тени (shadow mapping) и как они используются?'],
#  'геймдизайн': ['1. Какие основные компоненты должны быть в геймдизайне?',
#   '2. Как определить, какая тематика должна быть применена на игровом месте?',
#   '3. Какие виды светодиодов можно использовать для светотилей на геймдизайне?',
#   '4. Какие методы можно использовать для изображения гиф и анимированных объектов в геймдизайне?',
#   '5. Что такое "интерактивные элементы" на геймдизайне и как их интегрировать?',
#   '6. Какие методы могут использоваться для создания геймдизайна для разных устройств?',
#   '7. Как создать геймдизайн, который будет корректно работать на различных разрешениях экрана?',
#   '8. Как можно создать геймдизайн, который поддерживает различные разрешения и ориентации экранов?',
#   '9. Какие факторы нужно учитывать при создании геймдизайна, чтобы обеспечить лучшую доступность?',
#   '10. Как можно применить принципы дизайна, чтобы сделать геймдизайн более эстетичным?',
#   '11. Какие методы можно использовать для создания геймдизайна, который будет отличаться от стандартных?',
#   '12. Какие методы могут использоваться для создания геймдизайна с использованием только текста?',
#   '13. Как создать геймдизайн, который будет понятен и привлекать внимание пользователя на разных устройствах?',
#   '14. Какие методы могут использоваться для создания геймдизайна, который будет поддерживать различные модели игровых контроллеров?'],
#  'разработка мобильных приложений': ['1. Какие инструменты необходимо использовать для создания мобильных приложений для iOS и Android?',
#   '2. Что нужно знать о системных ресурсах и API для мобильных приложений?',
#   '3. Как управлять состоянием приложения на iOS и Android?',
#   '4. Что такое адаптивный дизайн?',
#   '5. Как оптимизировать производительность мобильных приложений?',
#   '6. Что такое обратная связь (feedback) и как ее использовать для улучшения приложения?',
#   '7. Как работает расширяемость (extensions) на мобильных платформах?',
#   '8. Что такое облако платформы для мобильных приложений (mobility cloud)?',
#   '9. Как обеспечить безопасность мобильных приложений?',
#   '10. Как использовать сервисы для мобильных приложений (APIs)?',
#   '11. Что такое разнообразие интерфейсов (UI) для мобильных приложений?',
#   '12. Как интегрировать мобильные приложения с сервисами внешнего мира (Web, social media)?',
#   '13. Как оптимизировать загрузку зависимостей приложения?',
#   '14. Что такое тестирование мобильных приложений?',
#   '15. Как использовать тестируемые разработки для мобильных приложений?',
#   '16. Как отслеживать и анализировать использование мобильных приложений?',
#   '17. Как использовать картографические данные в мобильных приложениях?',
#   '18. Что такое встроенные системные чаты (Voice over IP) для мобильных приложений?',
#   '19. Как работать с геолокацией в мобильных приложениях?',
#   '20. Как использовать виртуализацию для улучшения производительности мобильных приложений?'],
#  'разработка игр': ['**1. What is a game engine and what role does it play in game development?**',
#   '**2. Can you name some popular game engines used today?**',
#   '**3. What are the main components of a game engine?**',
#   '**4. What programming languages are commonly used for game development?**',
#   '**5. How does the game engine handle graphics rendering?**',
#   '**6. What is the purpose of an asset pipeline in game development?**',
#   '**7. How do game engines manage audio?**',
#   '**8. What is a game loop and why is it crucial?**',
#   '**9. Can you explain what middleware is and give examples?**',
#   '**10. What is the role of a game designer in the development process?**',
#   '**11. How does a game engine handle physics simulations?**',
#   '**12. What is the difference between 2D and 3D game development?**',
#   '**13. How do game engines handle user input?**',
#   '**14. How does a game engine handle networking and multiplayer?**',
#   "**15. What is a game engine's rendering engine?**",
#   '**16. How does a game engine handle AI and NPCs?**',
#   '**17. What is a scene graph?**',
#   '**18. How do game engines handle animation?**',
#   '**19. What is the concept of "assets" in game development?**',
#   '**20. How do game engines manage game states and transitions?**']}

# %%
ra = context_q_gen([
    "большие данные"
])
ra
# Out:
# 100%|██████████| 1/1 [00:18<00:00, 18.71s/it]
# {'большие данные': ['1. Какие типы данных имеют наибольшие размеры в Python?',
#   '2. Как определить размер определенного типа данных в Python?',
#   '3. Как можно получить информацию о размере потока в Python?',
#   '4. Как можно изменить размер определенного типа данных в Python?',
#   '5. Как можно сохранить большие данные в файл на диск?',
#   '6. Как можно считывать большие данные из файла на диск?',
#   '7. Как можно уменьшить размер больших данных в памяти?',
#   '8. Как можно создать большой массив в Python?',
#   '9. Как можно использовать базу данных для хранения больших данных?',
#   '10. Как можно преобразовать большие данные в другой тип данных?',
#   '11. Как можно определить тип данных в больших списках?',
#   '12. Как можно сравнить размеры разных типов данных?',
#   '13. Как можно проверить, является ли данные потоком?',
#   '14. Как можно считывать данные из потока в Python?',
#   '15. Как можно разделить большие данные на несколько частей?',
#   '16. Как можно объединить несколько частей больших данных в один?',
#   '17. Как можно сохранить большие данные в различные файлы?',
#   '18. Как можно извлечь данные из файла, содержащего большие данные?',
#   '19. Как можно создать большой массив из множества?',
#   '20. Как можно использовать сжатие данных для уменьшения размера?']}

# %%
r.update(ra)
r
# Out:
# {'алгоритмы': ['. Можете ли описать, почему для решения задач алгоритмического программирования используются различные структуры данных, и выделить примеры, когда каждая структура данных имеет преимущество перед остальными? Ответ: Алгоритмическое программирование — это процесс построения эффективных алгоритмов для решения конкретных задач. Используются различные структуры данных для оптимизации времени и пространства поддержания информации, чтобы обеспечить быстродействие алгоритмов. Вот основные структуры данных и примеры их применения:'],
#  'структуры данных': ['2. Как работает опциональность свойств в объектах в JavaScript?',
#   '3. Как создать объект с замыканием и приватными свойствами?',
#   '4. Что такое свойства глобального контекста (global object) в JavaScript?',
#   '5. Почему использование замыканий может быть полезно при работе с объектами?',
#   '6. Какие особенности в работе с объектами в TypeScript?',
#   '7. В чем преимущества использования классов для создания объектов, по сравнению с прототипной моделью?',
#   '8. Как можно определить, является ли объект прототипом другого объекта или прототипом прототипа?',
#   '9. Что такое прототипное наследование в JavaScript и как оно работает?',
#   '10. Как использовать метод `Object.getPrototypeOf()` для получения прототипа объекта?',
#   '2. Как использовать метод `Array.prototype.map()` для манипуляции массивом?',
#   '3. Что происходит при создании массива с помощью шаблонного литерала?',
#   '4. Как работает метод `Array.prototype.filter()`? Примером продемонстрируйте его использование.',
#   '5. Отличие между `Array.prototype.slice()` и `Array.prototype.splice()`?',
#   '6. Как создать и отсортировать массив с использованием `Array.prototype.sort()`?',
#   '7. Что такое массив-объект и как его использовать?'],
#  'обработка исключений': ['1. Что такое исключение в программировании?',
#   '2. Какие типы исключений существуют в Python?',
#   '3. Как можно отлавливать исключения в блоке try/except?',
#   '4. Как использовать finally для выполнения кода после try/except?',
#   '5. Как можно перехватывать исключения в Python с помощью try/except?',
#   '6. Как использовать else в блоке try/except для выполнения кода, если никаких исключений не возникло?',
#   '7. Как можно использовать finally для освобождения ресурсов, независимо от возникновения исключений?',
#   '8. Как обрабатывать исключения в методах классов Python?',
#   '9. Как использовать raise для выбрасывания исключения в Python?',
#   '10. Как можно определить пользовательские исключения в зависимости от ситуации?',
#   '11. Как использовать contextlib для создания менеджера контекста для обработки исключений?',
#   '12. Как использовать assert для проверки условий и выбрасывания исключения AssertionError?',
#   '13. Как использовать logging для логирования исключений?',
#   '14. Как использовать finally для закрытия файлов и других ресурсов?',
#   '15. Как использовать try/except для обработки исключений в цикле?',
#   '16. Как использовать try/except для обработки исключений в функции?',
#   '17. Как использовать try/except для обработки исключений в классе?',
#   '18. Как использовать try/except для обработки исключений в модуле?',
#   '19. Как использовать try/except для обработки исключений в контексте?'],
#  'обработка ошибок': ['Q: Какую роль играет обработка ошибок в модели приложения?'],
#  'файловая система': [],
#  'операционная система': [],
#  'работа с файлами': ['1. Как вы обнаружите и исправите пропуски в данных файла?',
#   '2. Какие методы вы использовали для проверки целостности данных в файле?',
#   '3. Какие инструменты или библиотеки вы предпочитаете для работы с файлами?',
#   '4. Как вы бы организовали структуру файлов в вашей среде разработки?',
#   '5. Какие техники и методы вы используете для оптимизации работы с большими файлами?',
#   '6. Как бы вы обрабатывали ситуацию, когда файл в вашем проекте был поврежден или потерян?',
#   '7. Какие инструменты или технологии вы используете для резервного копирования файлов?',
#   '8. Как вы бы решили проблему с несоответствием данных между файлами?',
#   '9. Какие методы использовали бы вы для поиска ошибок в коде файлов?',
#   '10. Как бы вы реализовали функцию, которая позволит легко найти определенный тип файлов в вашем проекте?',
#   '11. Как бы вы переименовывали файлы, чтобы они лучше отражали их содержание?',
#   '12. Какие инструменты или библиотеки вы используете для работы с JSON файлами?',
#   '13. Как бы вы организовали хранение и обработку временных файлов в вашем проекте?',
#   '14. Как бы вы реализовали система для работы с файлами в разных форматах (JSON, CSV, XML, Batch)?'],
#  'типы файлов': ['# 1. Какой тип файла используется для хранения конфигурационных параметров?',
#   '# 2. Какой тип файла используется для сохранения данных в формате CSV?',
#   '# 3. Какой тип файла используется для хранения документов в формате DOCX?',
#   '# 4. Какой тип файла используется для хранения изображений в формате JPEG?',
#   '# 5. Какой тип файла используется для хранения видео в формате MP4?',
#   '# 6. Какой тип файла используется для хранения исполняемых файлов программного обеспечения?',
#   '# 7. Какой тип файла используется для хранения текстовых данных в формате TXT?',
#   '# 8. Какой тип файла используется для хранения архивных файлов в формате ZIP?',
#   '# 9. Какой тип файла используется для хранения изображений в формате PNG?',
#   '# 10. Какой тип файла используется для хранения видео в формате AVI?',
#   '# 11. Какой тип файла используется для хранения исполняемых файлов программного обеспечения в формате EXE?',
#   '# 12. Какой тип файла используется для хранения текстовых данных в формате RTF?',
#   '# 13. Какой тип файла используется для хранения архивных файлов в формате 7z?',
#   '# 14. Какой тип файла используется для хранения исполняемых файлов программного обеспечения в формате BAT?',
#   '# 15. Какой тип файла используется для хранения текстовых данных в формате HTML?'],
#  'кодирование файлов': ['# Answer:1. Как можно избежать использования повторяющихся кодовых слов в коде?',
#   '2. Как правильно объявлять глобальные переменные в функциях?',
#   '3. Как сделать код более читаемым и легким для понимания?',
#   '4. Как оптимизировать алгоритм сортировки для больших данных?',
#   '5. Как избежать ошибок в работе с памятью при работе с большими файлами?',
#   '6. Как правильно обрабатывать исключения в программе?',
#   '7. Как можно улучшить эффективность циклов в программе?',
#   '8. Как уменьшить количество повторяющихся данных?',
#   '9. Как правильно использовать вложенные циклы?',
#   '10. Как оценить сложность алгоритмов и функций?',
#   '11. Как правильно работать с файловой системой?',
#   '12. Как правильно использовать параметры функций?',
#   '13. Как улучшить отладку кода?',
#   '14. Как правильно использовать конструкции циклического обхода и ветвления?',
#   '15. Как правильно использовать строковые операции для работы с данными?',
#   '16. Как правильно использовать исключения и флаги в условиях?',
#   '17. Как правильно использовать конструкции циклического обхода с итераторами?',
#   '18. Как правильно использовать циклы с прерыванием?',
#   '19. Как правильно использовать множества в программе?',
#   '20. Как правильно использовать исключения и флаги в условиях с разными типами данных?'],
#  'базы данных': ['1. Какая структура базы данных оптимальна для хранения большого количества однонаправленных однодокументных данных?',
#   '2. Что такое "запрос сервер-оператора базы данных" (DSN)?',
#   '3. В какой последовательности выполняются SQL-запросы: объединения, поиск, отфильтровать и выборка?',
#   '4. Как называется операция, позволяющая изменить структуру таблицы в базе данных без изменения данных?',
#   '5. Что означает " транзакция" в контексте баз данных?',
#   '6. Как называется операция отображения данных из базы данных для пользователей?',
#   '7. Как называется операция для добавления новых данных в таблицу или базу данных?',
#   '8. Что такое "хеш-функция" и зачем её нужно в базах данных?',
#   '9. Что делает "индекс" в базе данных?',
#   '10. Что такое "возрастной индекс" (orc index) в MySQL?',
#   '11. Как называется операция, позволяющая удалить данные из таблицы или базы данных?',
#   '12. Что такое "операция сортировки" (ORDER BY) в SQL?',
#   '13. Как называется операция, позволяющая сохранять данные в базу данных?'],
#  'SQL': ['1. Как можно выбрать только те записи, для которых дата и время существуют?',
#   '2. Как подсчитать количество записей, где значение в столбце `column_name` больше 100?',
#   '3. Как объединить данные из двух таблиц, если они имеют общий столбец `id`?',
#   '4. Как создать индекс на столбец `column_name` для ускорения поиска?',
#   '5. Как написать запрос, который выдаст информацию о последних 10 записях?',
#   '6. Как изменить значение в таблице, если определенная запись уникальна по определенному столбцу?',
#   '7. Как удалить все записи, где значение в столбце `column_name` равно 0?',
#   '8. Как создать таблицу, которая содержит столбцы `id`, `name`, `surname`?',
#   '9. Как отфильтровать записи, где столбец `column_name` содержит определенный текст?',
#   '10. Как добавить новый столбец в таблицу?',
#   '11. Как обновить значение в столбце `column_name` для определенной записи?',
#   '12. Как удалить все записи из таблицы, не содержащих определенный текст в столбце `column_name`?',
#   '13. Как выбрать записи, удовлетворяющие условию в столбце `column_name`, и если они не удовлетворяют, добавить их в новую таблицу?',
#   '14. Как создать индекс на несколько столбцов для ускорения поиска?',
#   '15. Как создать таблицу с тремя столбцами и заполнить ее данными?'],
#  'не реляционные базы данных': ['1. Какая технология позволяет интегрировать не реляционные базы данных с популярными веб-фреймворками?',
#   '2. Как называется процесс конвертации данных из реляционной базы в не реляционную?',
#   '3. В каких случаях использование не реляционных баз данных может привести к увеличению производительности?',
#   '4. Что такое "партикловение" в контексте не реляционных баз данных?',
#   '5. Каковы основные типы данных, поддерживаемые в не реляционных базах данных?',
#   '6. Какие методы используются для решения проблемы "много коллинеарности" в матричных данных?',
#   '7. Как называется подход к хранению данных, где данные хранятся в виде отдельных файлов на файловой системе?',
#   '8. Какие особенности облачных баз данных отличают их от накопительных?',
#   '9. В чём состоит проблема "много коллинеарности" и какие инструменты предлагаются для её решения?',
#   '10. Как называется процесс, при котором данные начинают сжиматься при больших объемах хранения?',
#   '11. Как называется процесс, при котором данные становятся нечитаемыми в базах данных?',
#   '12. Что такое "сжатие данных" и какие техники используются для его реализации?',
#   '13. Какие факторы влияют на точность полученных результатов при использовании не реляционных баз данных?',
#   '14. Какие ключевые фазы в разработке не реляционных баз данных?'],
#  'распределенные базы данных': ['1. Какие основные типы распределенных баз данных существуют?',
#   '2. Что такое ключевое слово SLA (Service Level Agreement) в контексте распределенных баз данных?',
#   '3. Какие проблемы могут возникнуть при взаимодействии с распределенными базами данных?',
#   '4. Что такое "операция транзакции" и зачем она нужна в распределенных системах?',
#   '5. Как происходит репликация данных в распределенных базах данных?',
#   '6. Что такое "оплата за резервное копирование" и как это работает?',
#   '7. Что такое "оплата на точность"? Как это может выглядеть в реальной бизнес-системе?',
#   '9. Какие вещи необходимо учитывать при выборе реализации распределенной базы данных?',
#   '11. Что такое "оплата по минимальной точности" и как это может быть реализовано?',
#   '12. Как определить приемлемый уровень "оплаты по точности" для вашей бизнес-системы?',
#   '14. Какие параметры оцениваются при "оплате по точности"?',
#   '15. Что такое "оплата на скорость" и как оно реализуется в распределенных базах данных?',
#   '16. Какие проблемы могут возникнуть при реализации "оплаты на скорость"?'],
#  'большие данные': ['1. Какие типы данных имеют наибольшие размеры в Python?',
#   '2. Как определить размер определенного типа данных в Python?',
#   '3. Как можно получить информацию о размере потока в Python?',
#   '4. Как можно изменить размер определенного типа данных в Python?',
#   '5. Как можно сохранить большие данные в файл на диск?',
#   '6. Как можно считывать большие данные из файла на диск?',
#   '7. Как можно уменьшить размер больших данных в памяти?',
#   '8. Как можно создать большой массив в Python?',
#   '9. Как можно использовать базу данных для хранения больших данных?',
#   '10. Как можно преобразовать большие данные в другой тип данных?',
#   '11. Как можно определить тип данных в больших списках?',
#   '12. Как можно сравнить размеры разных типов данных?',
#   '13. Как можно проверить, является ли данные потоком?',
#   '14. Как можно считывать данные из потока в Python?',
#   '15. Как можно разделить большие данные на несколько частей?',
#   '16. Как можно объединить несколько частей больших данных в один?',
#   '17. Как можно сохранить большие данные в различные файлы?',
#   '18. Как можно извлечь данные из файла, содержащего большие данные?',
#   '19. Как можно создать большой массив из множества?',
#   '20. Как можно использовать сжатие данных для уменьшения размера?'],
#  'ИИ': ['## Response:1. Что такое искусственный интеллект (ИИ)?',
#   '2. Какова роль нейронных сетей в разработке ИИ-систем?',
#   '3. Как машинное обучение используется в ИИ?',
#   '4. Что такое искусственный интеллект-обучение по сетям (AI-SGD)?',
#   '5. Каковы основные виды ИИ-программ?',
#   '6. Как работает нейронная сеть в обработке данных?',
#   '7. Как нейронная сеть учится с помощью данных?',
#   '8. Что такое нейронная сеть в ИИ?',
#   '9. Какова роль обработки картинок в ИИ?',
#   '10. Как нейронные сети работают с аудио-данными?',
#   '11. Как нейронные сети могут использоваться для распознавания голоса?',
#   '12. Как нейронные сети могут быть использованы для прогнозирования временных рядов?',
#   '13. Как нейронные сети используются в обработке речи?',
#   '14. Как нейронные сети обучаются в задачах классификации?',
#   '15. Как нейронные сети могут быть использованы для решения задач обработки естественного языка?',
#   '16. Как нейронные сети могут быть использованы для решения задач компьютерного зрения?',
#   '17. Какова роль нейронных сетей в машинном переводе?',
#   '18. Как нейронные сети могут быть использованы в задачах машинного обучения?',
#   '19. Каковы основные принципы машинного обучения?',
#   '20. Каковы преимущества ИИ над ручной обработкой данных?'],
#  'интернет вещей': ['- Какие технологии используются для создания виртуального реального мире?',
#   '- Как работает интернет-магазин, если он не использует реальные товары?',
#   '- Как создается эффект виртуальной реальности?',
#   '- Как можно реализовать интеллектуальную общаjemь без уникальных концепций?',
#   '- Как можно соединить физическое и виртуальное пространство в приложениях?',
#   '- Как создается и используется сценарий в игре?',
#   '- Как создается виртуальная пространство для игр?',
#   '- Как работает виртуальная реальность в играх?',
#   '- Как создается и взаимодействует с ней виртуальная реальность?',
#   '- Как можно создать виртуальный мир, который будет обновляться в реальном времени?'],
#  'машинное обучение': [', но с подробными объяснениями. Приведите ответы, если отвечаете на вопросы. **1. Физика**1. Физика - это наука о физических процессах. Чем она распространилась? Физика распространилась с древних времен по всему миру. Например, в древние Индии, Греции, Греции, а также в Европе.2. Модель мира, которая используется в физике, называется блоками-моделью мира (block model universe). В этой модели наблюдаемые явления можно разделить на блоки. Какие блоки составляют блок-модель мира? Блок-модель мира состоит из физических, биоисходных и космических блоков.3. Как математический анализ применяется в физике? Для оптимизации физических моделей, согласно теории максимума информации.4. Как работает термометр? Термометр работает на основе термодинамической теории, описывающей движение и ускорение тел. Она основана на принципе сохранения энергии.5. Как работает амперметр? Амперметр используется для измерения напряжения в потенциаловых энергетических связах.6. Что такое квантовая физика? Квантовая физика - это физика, описывающая поведение на уровне микроклимата и микромассы.7. Как работает накалочный аппарат? Накалочный аппарат с помощью накалочек из электромагнитных материалов изменяет плотность электрического поля в пространстве.8. Как работает индуктивный реле? Индуктивный реле использует механизм индукции для измерения изменения напряжения. Как работает электронная тачка? Электронная тачка работает на основе электрического то'],
#  'обучение без учителя': ['1. Как обучать ребенка без учебника?',
#   '2. Как научить ребенка читать?',
#   '3. Как научить ребенка играть на инструментах?',
#   '4. Как дать ребенка первое мнение?',
#   '5. Как научить ребенка играть в компьютерную игру?',
#   '6. Как научить ребенка играть в видеоигры?',
#   '7. Как научить ребенка играть в компьютерную музыку?',
#   '8. Как научить ребенка играть в роле в игре?',
#   '9. Как научить ребенка играть в роли в кинопрограмме?',
#   '10. Как научить ребенка играть в роли в динамической игре?',
#   '11. Как научить ребенка играть в роли в режиме 3D?',
#   '12. Как научить ребенка играть в роли в реальном времени?',
#   '13. Как научить ребенка играть в роли в динамическом роле?',
#   '14. Как научить ребенка играть в роли в мультиплексированных играх?',
#   '15. Как научить ребенка играть в роли в играх с интерфейсом?',
#   '16. Как научить ребенка играть в роли в играх с физикой?',
#   '17. Как научить ребенка играть в роли в играх с анимацией?',
#   '18. Как научить ребенка играть в роли в играх с видео?"',
#   '1. Как приготовить обед с помощью листьев?',
#   '2. Как использовать листья в приготовлении обеда?'],
#  'проклятье размерностей': ['1. Что является основным原因 для использования размерности в данных?',
#   '2. Как называется размерность, которая отражает количество уникальных направлений, в которых данные умеют расширяться?',
#   '3. Что такое многомерный массив?',
#   '4. Что такое метаданные в контексте данных?',
#   '5. Что такое данные с высокой размерностью?',
#   '6. Как называется ситуация, когда данные имеют слишком высокие или слишком низкие размерности?',
#   '7. Что такое разрядность?',
#   '8. Что такое плотность в контексте данных?',
#   '9. Что такое структура данных?',
#   '10. Что такое данные с низкой размерностью?',
#   '11. Как называется изображение с небольшим количеством различных цветов?',
#   '12. Что такое яркость в контексте изображений?',
#   '13. Как называется изображение с большим количеством различных цветов?',
#   '14. Что такое контрастность в контексте изображений?',
#   '15. Что такое отображение в контексте данных?',
#   '16. Что такое визуализация данных?',
#   '17. Что такое отображение и визуализация в контексте данных?',
#   '18. Что такое данные с высокой яркостью?',
#   '19. Как называется изображение с низкой контрастностью?',
#   '20. Что такое данные с высокой структурой?'],
#  'статистика': ['1. What is the difference between descriptive and inferential statistics?',
#   '2. How do you calculate the mean of a set of numbers?',
#   '3. What is a mode, and how do you find it in a dataset?',
#   '4. How is the median of a dataset determined?',
#   '6. How can you interpret the correlation coefficient?',
#   '7. What is a p-value in hypothesis testing?',
#   '8. How do you construct a confidence interval?',
#   '9. What is a Z-score, and what does it indicate?',
#   '10. What are the assumptions behind a t-test?',
#   '11. How do you calculate the chi-square statistic?',
#   '12. What is a regression analysis, and why is it useful?',
#   '13. How do you determine if a sample is representative of a population?',
#   '14. What is the difference between a parametric and non-parametric test?',
#   '15. How do you perform a one-sample z-test?',
#   '16. What is the purpose of a two-sample t-test?',
#   '17. How can you assess the goodness of fit of a model?',
#   '18. What is the purpose of a chi-square goodness-of-fit test?',
#   '19. How do you interpret the results of an ANOVA test?',
#   '20. What is a power analysis, and why is it important in hypothesis testing?',
#   '1. What is the difference between descriptive and inferential statistics?',
#   '2. How do you calculate the mean of a set of numbers?',
#   '3. What is a mode, and how do you find it in a dataset?',
#   '4. How is the median of a dataset determined?',
#   '6. How can you interpret the correlation coefficient?',
#   '7. What is a p-value in hypothesis testing?',
#   '8. How do you construct a confidence interval?',
#   '9. What is a Z-score, and what does it indicate?'],
#  'линейная алгебра': ['## Solution:1. What is the dimension of the vector space consisting of all 2x2 matrices?',
#   '3. What is the difference between a scalar and a vector?',
#   '6. What is the rank of a matrix and how is it determined?',
#   '9. What does it mean for two vectors to be orthogonal?',
#   '11. What is a matrix representation of a linear transformation?',
#   '12. What does it mean for a matrix to be invertible?',
#   '14. What is the geometric interpretation of a linear transformation?',
#   '17. What is the condition for a matrix to be symmetric?',
#   '19. What is the geometric interpretation of a determinant?'],
#  'математический анализ': ['11. Если нужно найти значение интеграла функции s(x) = e^x в промежутке [0, 2], как это сделать?'],
#  'обучение с подкреплением': ['Q1: Что такое обучение с подкреплением?',
#   'Q2: В чем разница между обучением с подкреплением и традиционным обучением?',
#   'Q3: Какие есть типы подкрепления в обучении с подкреплением?',
#   'Q4: Какие технологии используются для обучения с подкреплением?',
#   'Q5: Как обучение с подкреплением используется в образовательном контексте?',
#   'Q6: В чем преимущества использования обучения с подкреплением по сравнению с традиционным обучением?',
#   'Q7: Как обучение с подкреплением улучшает память и концентрацию?',
#   'Q8: В каких областях обучение с подкреплением может быть особенно полезен?',
#   'Q9: Как обучение с подкреплением может помочь в решении проблем?',
#   'Q10: Как обучение с подкреплением помогает в развитии навыков социальной коммуникации?',
#   'Q11: Какие виды подкрепления используются в обучении с подкреплением?',
#   'Q12: Как обучение с подкреплением помогает в развитии творческого мышления?',
#   'Q13: Как обучение с подкреплением помогает в укреплении памяти?',
#   'Q14: Как обучение с подкреплением может оптимизировать процесс обучения?',
#   'Q15: Как обучение с подкреплением помогает в развитии самостоятельности?',
#   'Q16: Какие проблемы могут возникнуть при использовании обучения с подкреплением?'],
#  'СУБД': ['1. Что такое реляционное база данных?',
#   '2. Какие основные операции позволяют управлять данными в реляционной БД?',
#   '3. Что такое SQL?',
#   '4. Какие типы данных поддерживаются в SQL?',
#   '5. Как называется запрос, который определяет структуру данных в реляционной БД?',
#   '6. Что такое транзакция в контексте БД?',
#   '7. Что представляет собой иерархическую таблицу?',
#   '8. Как работает оптимизатор запросов в SQL?',
#   '9. Что такое внешний ключ в SQL?',
#   '10. Что такое ограничение уникальности в SQL?',
#   '11. Как называется запрос, который выбирает данные из одной или нескольких таблиц?',
#   '12. Что такое индекс в реляционной БД?',
#   '13. Что такое внешний источник данных?',
#   '14. Как называется запрос, который создает новую таблицу или изменяет существующую?',
#   '15. Что такое атрибут в контексте таблицы БД?',
#   '16. Что такое запрос, который изменяет структуру данных таблицы БД?',
#   '17. Что такое ключ первичный в SQL?',
#   '18. Как называется запрос, который удаляет данные из таблицы?',
#   '19. Что такое наличие данных в БД?',
#   '20. Что такое последовательность в SQL?'],
#  'антифрод системы': ['Q1. Какие основные виды и классы антифрод системы?',
#   'Q2. Как работают системы антифрод в облаке?',
#   'Q3. В чем разница между системыми антифрод и приложениями антифрод?',
#   'Q4. Какие технологии используются при разработке современных антифрод систем?',
#   'Q5. Что такое менеджмент антифрод?',
#   'Q6. Какие технологии используются для защиты от вирусов в облаке?',
#   'Q7. Как система антифрод определяет, что происходит атака?',
#   'Q8. В чем разница между защитой от вирусов на уровне приложений и на уровне операционной системы?',
#   'Q9. Какие методы использоваются для обнаружения и предотвращения атак злоумышленников?',
#   'Q10. Какие угрозы представляют собой массовое распространение вируса в облаке?',
#   'Q11. Как система антифрод может обнаружить и предотвратить распространение вредоносного кода?',
#   'Q12. Какие подходы используются при разработке защиты от вирусов для операционных систем?',
#   'Q13. Как система антифрод может определить, что вирус является новым или известным?',
#   'Q14. Как система антифрод обеспечивает безопасность на уровне приложений?',
#   'Q15. Какие методы используются для защиты от атаки через поиск в сети?',
#   'Q16. Как система антифрод может защитить информацию в облаке?',
#   'Q17. Какие методы используются для защиты от атаки на сеть?',
#   'Q18. Как система антифрод обеспечивает защиту от вредоносного кода в облаке?',
#   'Q19. Как работали в прошлый раз методы защиты от вирусов в облаке?'],
#  'рекомендательные системы': ['1. Каковы основные компоненты рекомендательной системы?',
#   '2. Что такое социальная сеть в контексте рекомендательных систем?',
#   '3. Каковы преимущества и недостатки рекомендаций на основе входных данных?',
#   '4. Как работают эмбеддинги в рекомендательных системах?',
#   '5. В чем разница между моделями рекомендаций "как нибудь" и "как еще"?',
#   '6. Как определяются метрики для оценки качества рекомендаций?',
#   '7. Как рекомендательные системы могут быть защищены от межпользовательских угроз?',
#   '8. Как рекомендации могут быть персонализированы для пользователя?',
#   '9. Как происходит масштабирование рекомендательных систем для больших пользовательских баз?',
#   '10. Как рекомендательные системы учитывают изменения в предпочтениях пользователя?',
#   '11. Как рекомендательные системы учитывают контекст используемой информации?',
#   '12. Как рекомендательные системы обрабатывают аномальные данные пользователей?',
#   '13. Как рекомендательные системы учитывают временные факторы в предсказании?',
#   '14. Как рекомендательные системы относятся к понятию "управляемых рекомендаций"?',
#   '15. Как рекомендательные системы учитывают информацию о социальных сети?',
#   '16. Как рекомендательные системы учитывают контекстуальные факторы в рекомендациях?'],
#  'тестирование кода': [', так чтобы они были сложными и требовали глубокого понимания. Тема - Тестирование кода. 1. Какие принципы и практики при разработке тестирования кода помогают обеспечить его качество и надежность? (4)',
#   '2. Как можно оценить сложность теста, а также уверенность в том, что тест пройдет успешно, и применимые методы для определения стоимости тестирования? (4)',
#   '3. Какие методы и инструменты используются для автоматизации тестирования и какие преимущества они представляют? (4)',
#   '4. Как можно определить минимальное тестируемое код? (4)',
#   '5. Какие факторы могут повлиять на то, как реализуется и устроен процесс тестирования в команде разработчиков? (4)',
#   '6. Как происходит интеграционное и агрегационное тестирование в процессе разработки программного обеспечения? (4)',
#   '7. Как можно определить, какие тесты следует выполнить для удовлетворения пользовательского ожидания? (4)',
#   '8. Какие лучшие практики помогают избежать дублирования кода в коде? (4)',
#   '9. Какие методы используются для обнаружения и исправления дефектов в коде? (4)',
#   '10. Какие инструменты и методы используются для отслеживания и прогрессивного улучшения качества кода? (4)',
#   '11. Как можно обеспечить поддерживаемость и устойчивость кода в процессе внесения изменений и обновлений? (4)',
#   '12. Какие типы тестирования наиболее подходят для выявления потенциальных проблем в коде? (4)'],
#  'отладка кода': ['1. При компиляции программы на C# в Visual Studio не срабатывает автоматическое дебаггинг. Что необходимо сделать, чтобы включить автоматические дебаггинги?',
#   '2. В C# существует функция `Debug.Assert`, которая используется для проверки условий во время компиляции. Какие предупреждения отладчика выведет, если вы используете `Debug.Assert` в коде?',
#   '3. Как можно отключить автоматические дебаггинги в Visual Studio?'],
#  'компьютерная графика': ['1. Как называется процесс, при котором изображение на экране создается с использованием пикселей?',
#   '2. В чём отличие текстуры от мозаики?',
#   '3. Обобщите, что такое сглаживание (aliasing)?',
#   '4. Что такое ввод данных в компьютер?',
#   '5. Что такое последовательный размерности (sequential dimension)?',
#   '6. Что такое массив в компьютерных системах?',
#   '7. Что такое пространственная структура данных?',
#   '8. Что такое массив векторов?',
#   '9. Что такое многомерный массив?',
#   '10. Что такое массив 2х1 (array 2d)?',
#   '11. Как называется размерность n?',
#   '12. Что такое схема массивов?',
#   '13. Как называется утилита для сохранения текста?',
#   '14. Что такое скриптный язык программирования?',
#   '15. Что такое текстовый редактор?',
#   '16. Что такое утилита для отладки?',
#   '17. Что такое программа для создания видео на компьютере?',
#   '18. Что такое текстовый редактор со сжатием?',
#   '19. Что такое программа для работы с графикой?',
#   '20. Что такое интерпретатор?'],
#  'геймдизайн': ['1. Каков максимальный размер экрана для приложения, которое вы планируете разрабатывать?',
#   '2. Какие цвета вы хотите использовать в дизайне? Какие цвета могут создать особую атмосферу или эффект в вашем приложении?',
#   '3. Какой уровень сложности дизайна вы ожидаете у вашего целевой аудитории?',
#   '4. Какие функции или компоненты вам важно включать в ваше приложение?',
#   '5. Как вы планируете применять адаптивный дизайн? Какие аспекты вашего приложения будут динамически изменяться в зависимости от размера экрана?',
#   '6. Как вы планируете реализовать пользовательский интерфейс? Какие инструменты или фреймворки вы предпочитаете?',
#   '7. Какие возможности и функционал вы хотите отслеживать и измерять с помощью аналитики? Как вы планируете получать и отображать данные?',
#   '8. Как вы планируете углубить пользовательский интерес и удерживать его в вашем приложении?',
#   '9. Что вы планируете использовать для индивидуализации пользователей? Какие данные вы будете собирать и как вы их использовате?',
#   '10. Какие визуальные эффекты и анимации вы рассматриваете как полезными для вашего проекта?'],
#  'разработка мобильных приложений': ['1. Какие основные технологии используются для разработки мобильных приложений?',
#   '2. Что такое Android Studio и как оно отличается от Xcode?',
#   '3. Какие виды платформ существуют для мобильных приложений?',
#   '4. Как работает система управления версиями для мобильных приложений?',
#   '5. Как можно оптимизировать производительность мобильного приложения?',
#   '6. Как использовать сервисы Google Maps в мобильном приложении?',
#   '7. Как управлять имитацией пользователя в мобильных приложениях?',
#   '8. Как использовать фреймворк для работы с базами данных в мобильном приложении?',
#   '9. Как реализовать логику обработки данных в мобильном приложении?',
#   '10. Как интегрировать с картой в мобильное приложение?',
#   '11. Как использовать библиотеки для работы с аудио в мобильном приложении?',
#   '12. Какие правила и рекомендации следует соблюдать при разработке мобильных приложений?',
#   '13. Как подготовить мобильное приложение для публикации в App Store?',
#   '14. Как использовать API для интеграции с внешними сервисами в мобильное приложение?',
#   '15. Как реализовать систему авторизации в мобильном приложении?',
#   '16. Как использовать сервисы для отправки уведомлений в мобильное приложение?',
#   '17. Как создать иконку и заголовок для мобильного приложения?',
#   '18. Как использовать анимации и визуальные эффекты в мобильном приложении?',
#   '19. Как обрабатывать ошибки и исключения в мобильном приложении?'],
#  'разработка игр': ['1. Что такое "ожидание ответа" или "код ожидания" в игровой разработке?',
#   '2. Как создать игровую логику, которая реагирует на действия пользователя?',
#   '3. Что такое "пост-процессорность"? Как это используется в игровой программировании?',
#   '4. Как использовать навигационные компоненты в Unity для создания простых игровых элементов?',
#   '5. Что такое "интеграция с API" в игровом контексте? Приведите примеры.',
#   "6. Как использовать Unity's Animator для создания анимаций без скриптов?",
#   '7. Как создать простую физическую симуляцию в Unity?',
#   "8. Как использовать Unity's Particle System для создания эффектов в игре?",
#   '9. Как настроить звук в Unity для геймплеера?',
#   '11. Как создать собственный коллактор в Unity?',
#   "12. Как использовать Unity's NavMeshAgent для создания анимаций NPC?",
#   "13. Как использовать Unity's Behaviour Designer для создания поведения NPC?",
#   '14. Как настроить физическую симуляцию, чтобы объекты в Unity начали двигаться, когда игрок взаимодействует с ними?',
#   "15. Как использовать Unity's Terrain для создания сложных сцен?",
#   "16. Как использовать Unity's Lighting для создания атмосферы игры?",
#   "17. Как использовать Unity's UI для создания интерактивных элементов?",
#   "18. Как использовать Unity's Animator для создания анимаций персонажей?"]}

# %%
for k, v in r.items():
    r[k] = list(set(v + raa[k]))

# %%
with open("qs.pickle", "wb") as f:
    pickle.dump(r, f)

# %% [markdown]
# # LLM tests

# %%
def split_qs():
    with open("qs.pickle", "rb") as f:
        qs = pickle.load(f)
    
    new_qs = {"R1": {}, "R2": {}}
    for k, v in qs.items():
        edge = len(v)//2
        if edge > 2:
            new_qs["R1"][k] = v[:edge]
            new_qs["R2"][k] = v[edge:]
    return new_qs

def get_answers(qs, model):
    model_name = model.model.metadata["general.name"]
    answers = []
    pbar = tqdm(total=get_q_len(qs))

    c_num = len(qs)
    for c_count, (k, v) in enumerate(qs.items(), start=1):
        pbar.desc = f"{k} {c_count}/{c_num}"
        for q in v:
            tr={"Q": q, "category": k, "model": model_name}
            tr.update(model.generate(f"Ответь на вопрос: {q}"))
            answers.append(tr)
            pbar.update()
        pd.DataFrame(answers).to_csv(f"answers_{model_name}.csv", index=False)
    return answers

# %%
qs = split_qs()
print(get_q_len(qs["R1"]))
print(get_q_len(qs["R2"]))
# Out:
# 411
# 426

# %%
qm16 = SaigaShell(r"C:\Users\dmatr\Downloads\model-f16.gguf")

# %%
r = get_answers(qs["R1"], qm16)
# Out:
#   0%|          | 0/411 [00:00<?, ?it/s]

# %%
qm8 = SaigaShell(r"C:\Users\dmatr\Downloads\model-q8_0.gguf")
# Out:
# {'general.name': 'saiga_llama3_8b',
#  'general.architecture': 'llama',
#  'llama.block_count': '32',
#  'llama.context_length': '8192',
#  'tokenizer.ggml.eos_token_id': '128009',
#  'general.file_type': '7',
#  'llama.attention.head_count_kv': '8',
#  'llama.embedding_length': '4096',
#  'llama.feed_forward_length': '14336',
#  'llama.attention.head_count': '32',
#  'llama.rope.freq_base': '500000.000000',
#  'llama.attention.layer_norm_rms_epsilon': '0.000010',
#  'llama.vocab_size': '128256',
#  'llama.rope.dimension_count': '128',
#  'tokenizer.ggml.model': 'gpt2',
#  'tokenizer.ggml.pre': 'llama-bpe',
#  'general.quantization_version': '2',
#  'tokenizer.ggml.bos_token_id': '128000',
#  'tokenizer.ggml.padding_token_id': '128000',
#  'tokenizer.chat_template': "{% set loop_messages = messages %}{% for message in loop_messages %}{% set content = '<|start_header_id|>' + message['role'] + '<|end_header_id|>\n\n'+ message['content'] | trim + '<|eot_id|>' %}{% if loop.index0 == 0 %}{% set content = bos_token + content %}{% endif %}{{ content }}{% endfor %}{% if add_generation_prompt %}{{ '<|start_header_id|>assistant<|end_header_id|>\n\n' }}{% endif %}"}

# %%
r = get_answers(qs["R2"], qm8)
# Out:
#   0%|          | 0/426 [00:00<?, ?it/s]
