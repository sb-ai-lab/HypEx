# %%
import os
import time

from pyspark.sql import SparkSession

os.environ['OBJC_DISABLE_INITIALIZE_FORK_SAFETY'] = 'YES'

try:
    existing_spark = SparkSession.getActiveSession()
    if existing_spark:
        existing_spark.stop()
except:
    pass

for key in list(os.environ.keys()):
    if 'SPARK' in key or 'JAVA_OPTS' in key:
        del os.environ[key]

# --- 2. Cluster Configuration ---
# Format: local-cluster[num_workers, cores_per_worker, memory_per_worker_in_MB]
NUM_EXECUTORS = 2
CORES_PER_EXECUTOR = 6
MEMORY_PER_EXECUTOR_MB = 4096

MASTER_URL = f"local-cluster[{NUM_EXECUTORS}, {CORES_PER_EXECUTOR}, {MEMORY_PER_EXECUTOR_MB}]"

print(f"Running in mode: {MASTER_URL}")

sp_s = (SparkSession.builder
    .master(MASTER_URL)
    .appName("LocalClusterTest")
    .config("spark.driver.memory", "4g")
    .config("spark.executor.memory", "4g")
    .config("spark.executor.cores", "6")
    .config("spark.executor.instances", NUM_EXECUTORS)
    .config("spark.memory.fraction", "0.6")
    .config("spark.sql.shuffle.partitions", "4")  # For tests, less than the default 200
    .getOrCreate()
)

sp_s.sparkContext.setLogLevel("WARN")

# --- 3. Configuration Check ---
print("Session created.")
print(f"Driver Memory Config: {sp_s.conf.get('spark.driver.memory')}")
print(f"Executor Memory Config: {sp_s.conf.get('spark.executor.memory')}")

# Check the number of executors (may take a couple of seconds to start)
time.sleep(3)
num_executors = len(sp_s.sparkContext.parallelize(range(10), NUM_EXECUTORS).glom().collect())
print(f"📊 Active executors (checked via RDD): {num_executors}")

# --- 4. Distribution Test (Example) ---
# To make sure the task went to executors, not stayed on the driver
def print_executor_info(iterator):
    import os
    # Get the executor ID from the process environment variables
    executor_id = os.environ.get('SPARK_EXECUTOR_ID', 'Driver/Local')
    process_id = os.getpid()
    return [f"Executor ID: {executor_id}, PID: {process_id}"]

# Create a dataframe and apply a transformation
df = sp_s.range(0, 10, 1, 4)  # 4 partitions
result = df.rdd.mapPartitions(print_executor_info).collect()

print("\n🖥️ Where tasks were executed:")
for line in result:
    print(line)

sp_s
# Out:
# Running in mode: local-cluster[2, 6, 4096]
# 26/08/27 12:56:33 WARN Utils: Your hostname, MacBook-Pro-Danil.local resolves to a loopback address: 127.0.0.1; using 192.168.1.64 instead (on interface en0)
# 26/08/27 12:56:33 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/08/27 12:56:33 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/08/27 12:56:33 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/08/27 12:56:33 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# Session created.
# Driver Memory Config: 4g
# Executor Memory Config: 4g
# 📊 Active executors (checked via RDD): 2
#
# 🖥️ Where tasks were executed:
# Executor ID: Driver/Local, PID: 65631
# Executor ID: Driver/Local, PID: 65632
# Executor ID: Driver/Local, PID: 65640
# Executor ID: Driver/Local, PID: 65641
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.64:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local-cluster[2, 6, 4096]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>LocalClusterTest</code></dd>
#             </dl>
#         </div>
#
#             </div>
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 49688)
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socketserver.py", line 755, in __init__
#     self.handle()
#   File "/Users/danilsamsutdinov/HypEx/.venv/lib/python3.11/site-packages/pyspark/accumulators.py", line 295, in handle
#     poll(accum_updates)
#   File "/Users/danilsamsutdinov/HypEx/.venv/lib/python3.11/site-packages/pyspark/accumulators.py", line 267, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/Users/danilsamsutdinov/HypEx/.venv/lib/python3.11/site-packages/pyspark/accumulators.py", line 271, in accum_updates
#     num_updates = read_int(self.rfile)
#                   ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/danilsamsutdinov/HypEx/.venv/lib/python3.11/site-packages/pyspark/serializers.py", line 596, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------

# %% [markdown]
# # Matching pipeline

# %% [markdown]
# The comparison method is used in statistical analysis to eliminate distortions caused by differences in the basic characteristics of the studied groups. Simply put, matching helps to make sure that the results of the experiment are really caused by the studied effect, and not by external factors.
#
# Matching is most often performed in cases where the use of a standard AB test is impossible.

# %%
# imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from hypex import Matching
from hypex.dataset import (
    Dataset,
    FeatureRole,
    GroupingRole,
    InfoRole,
    TargetRole,
    TreatmentRole,
)
from hypex.utils import BackendsEnum, create_test_data

# %% [markdown]
# # Create synthetic data

# %%
df = create_test_data().bfill()
df["post_spends"] = df["pre_spends"] + np.random.rand(len(df))
df[["signup_month", "treat"]] = df[["signup_month", "treat"]].astype(int)
df
# Out:
#       user_id  signup_month  treat  pre_spends  post_spends   age gender  \
# 0         0.0             0      0       488.0   488.523614  42.0      F
# 1         1.0             0      0       468.5   468.630300  55.0      F
# 2         2.0            11      1       495.5   495.867873  29.0      F
# 3         3.0            10      1       477.0   477.488043  49.0      F
# 4         4.0            11      1       508.5   509.299976  27.0      M
# ...       ...           ...    ...         ...          ...   ...    ...
# 9995   9995.0             7      1       476.0   476.903098  19.0      M
# 9996   9996.0             6      1       457.0   457.454616  51.0      F
# 9997   9997.0             0      0       500.5   500.573528  44.0      F
# 9998   9998.0             4      1       502.0   502.519699  32.0      F
# 9999   9999.0             3      1       485.0   485.780808  47.0      F
#
#         industry
# 0     E-commerce
# 1      Logistics
# 2      Logistics
# 3     E-commerce
# 4     E-commerce
# ...          ...
# 9995  E-commerce
# 9996   Logistics
# 9997  E-commerce
# 9998  E-commerce
# 9999   Logistics
#
# [10000 rows x 8 columns]

# %%
def describe_basic_info(df: pd.DataFrame):
    print("Basic statistics for numerical features:")
    display(df.describe().round(2))

def describe_cltv_effect(df: pd.DataFrame, group_col="treat"):
    result = (
        df.groupby(group_col)[["pre_spends", "post_spends"]]
        .mean()
        .rename(columns={"pre_spends": "mean_pre_spends", "post_spends": "mean_post_spends"})
    )
    result["delta_spend"] = result["post_spends"] - result["pre_spends"]
    print("Average spend before and after pilot:")
    print(result.round(2))
    result.plot(
        kind="bar",
        figsize=(6, 4),
        title="Average spend before and after pilot by groups",
        rot=0
    )
    plt.ylabel("Average spend")
    plt.grid(alpha=0.3)
    plt.show()

    return result

def plot_cltv_distribution(df: pd.DataFrame):
    plt.figure(figsize=(7, 4))
    plt.hist(df["pre_spends"], bins=50, alpha=0.6, label="Before pilot")
    plt.hist(df["post_spends"], bins=50, alpha=0.6, label="After pilot")
    plt.title("spend distribution before and after pilot")
    plt.xlabel("pre_spends")
    plt.ylabel("Number of clients")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()


def full_dataset_report(df: pd.DataFrame):
    describe_basic_info(df)
    plot_cltv_distribution(df)

full_dataset_report(df)
# Out:
# Basic statistics for numerical features:
#        user_id  signup_month    treat  pre_spends  post_spends       age
# count  10000.0      10000.00  10000.0    10000.00     10000.00  10000.00
# mean    4999.6          2.97      0.5      487.47       487.97     43.67
# std     2886.9          3.74      0.5       18.78        18.78     14.92
# min        0.0          0.00      0.0      423.50       423.86     18.00
# 25%     2500.5          0.00      0.0      475.50       476.03     31.00
# 50%     5000.0          0.00      0.0      486.00       486.44     44.00
# 75%     7499.5          6.00      1.0      497.50       497.98     57.00
# max     9999.0         11.00      1.0      588.50       589.29     69.00

# %% [markdown]
# # Define the Dataset

# %%
data = Dataset(
    roles={
        "user_id": InfoRole(int),
        "treat": TreatmentRole(int),
        "post_spends": TargetRole(float),
        "gender": FeatureRole(str),
        "pre_spends": FeatureRole(float),
        "industry": FeatureRole(str),
        "age": FeatureRole(int),
    },
    data=df,
    default_role=InfoRole(),
    session=sp_s,
    backend=BackendsEnum.spark
)
data
# Out:
#      user_id signup_month treat pre_spends post_spends  age gender    industry
# 0          0            0     0      488.0  488.523614   42      F  E-commerce
# 1          1            0     0      468.5    468.6303   55      F   Logistics
# 2          2           11     1      495.5  495.867873   29      F   Logistics
# 3          3           10     1      477.0  477.488043   49      F  E-commerce
# 4          4           11     1      508.5  509.299976   27      M  E-commerce
# ...      ...          ...   ...        ...         ...  ...    ...         ...
# 9995    9995            7     1      476.0  476.903098   19      M  E-commerce
# 9996    9996            6     1      457.0  457.454616   51      F   Logistics
# 9997    9997            0     0      500.5  500.573528   44      F  E-commerce
# 9998    9998            4     1      502.0  502.519699   32      F  E-commerce
# 9999    9999            3     1      485.0  485.780808   47      F   Logistics
#
# 10000 rows × 8 columns

# %%
data.roles
# Out:
# {'user_id': Info(<class 'int'>),
#  'treat': Treatment(<class 'int'>),
#  'post_spends': Target(<class 'float'>),
#  'gender': Feature(data_type=<class 'str'>),
#  'pre_spends': Feature(data_type=<class 'float'>),
#  'industry': Feature(data_type=<class 'str'>),
#  'age': Feature(data_type=<class 'int'>),
#  'signup_month': Info(<class 'int'>)}

# %% [markdown]
# # Basic Matching without parameters
#
# Main matching steps (in HypEx):
#
# 1. **Dummy Encoder**
#    Converts categorical features to numerical format
#
# 2. **Distance matrix calculation (usually Mahalanobis)**
#
# 3. **Finding nearest pairs (via FAISS)**
#
# 4. **Quality check of twin matching**
#
# 5. **Effect estimation (ATT, ATC, ATE)**

# %%
data = data.fillna(method="bfill")
test = Matching()
result = test.execute(data)
# Out:
# 26/08/27 12:57:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:40 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:42 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:43 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:47 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:47 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:49 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# /Users/danilsamsutdinov/HypEx/hypex/dataset/backends/spark_backend.py:94: UserWarning: SparkContext checkpoint directory is not set. Falling back to local_checkpoint, which is NOT fault-tolerant and may fail if an executor is lost. Please set sc.setCheckpointDir('hdfs://...') for large jobs.
#   warnings.warn(
# 26/08/27 12:57:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:55 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# /Users/danilsamsutdinov/HypEx/hypex/dataset/backends/spark_backend.py:94: UserWarning: SparkContext checkpoint directory is not set. Falling back to local_checkpoint, which is NOT fault-tolerant and may fail if an executor is lost. Please set sc.setCheckpointDir('hdfs://...') for large jobs.
#   warnings.warn(
# /Users/danilsamsutdinov/HypEx/hypex/dataset/backends/spark_backend.py:94: UserWarning: SparkContext checkpoint directory is not set. Falling back to local_checkpoint, which is NOT fault-tolerant and may fail if an executor is lost. Please set sc.setCheckpointDir('hdfs://...') for large jobs.
#   warnings.warn(
# 26/08/27 12:57:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:57:58 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/08/27 12:58:00 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 26/08/27 12:58:00 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK
# /Users/danilsamsutdinov/HypEx/hypex/dataset/backends/spark_backend.py:94: UserWarning: SparkContext checkpoint directory is not set. Falling back to local_checkpoint, which is NOT fault-tolerant and may fail if an executor is lost. Please set sc.setCheckpointDir('hdfs://...') for large jobs.
#   warnings.warn(
# 2026-08-27 12:58:03 | ERROR    | hypex.experiment | ✗ Process failed: Chi2Test after 0.170s - AssertionError: exprs should not be empty
# 2026-08-27 12:58:03 | ERROR    | hypex.experiment | ✗ Process failed: OnRoleExperiment after 1.239s - AssertionError: exprs should not be empty
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 data = data.fillna(method="bfill")
#       2 test = Matching()
# ----> 3 result = test.execute(data)
#
# File ~/HypEx/hypex/ui/base.py:190, in ExperimentShell.execute(self, data)
#     188 if isinstance(data, Dataset):
#     189     data = ExperimentData(data)
# --> 190 result_experiment_data = self._experiment.execute(data)
#     191 self._out.extract(result_experiment_data)
#     192 return self._out
#
# File ~/HypEx/hypex/utils/profiling.py:140, in timeit.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     138 should_profile = enabled if enabled is not None else _PROFILING_ENABLED
#     139 if not should_profile:
# --> 140     return func(*args, **kwargs)
#     142 # Determine function/method name
#     143 class_name = ""
#
# File ~/HypEx/hypex/experiments/base.py:200, in Experiment.execute(self, data)
#     198         cur_executor = self._get_executor_backend(executor, experiment_data.ds)
#     199         cur_executor.key = self.key
# --> 200         experiment_data = cur_executor.execute(experiment_data)
#     201 return experiment_data
#
# File ~/HypEx/hypex/utils/profiling.py:140, in timeit.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     138 should_profile = enabled if enabled is not None else _PROFILING_ENABLED
#     139 if not should_profile:
# --> 140     return func(*args, **kwargs)
#     142 # Determine function/method name
#     143 class_name = ""
#
# File ~/HypEx/hypex/experiments/base.py:323, in OnRoleExperiment.execute(self, data)
#     321         data.ds.tmp_roles = tmp_roles_dict
#     322         self.executors = vector_executors
# --> 323         data = super().execute(data)
#     324         data.ds.tmp_roles = {}
#     326 # Iterative executors execution (one by one)
#
# File ~/HypEx/hypex/utils/profiling.py:140, in timeit.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     138 should_profile = enabled if enabled is not None else _PROFILING_ENABLED
#     139 if not should_profile:
# --> 140     return func(*args, **kwargs)
#     142 # Determine function/method name
#     143 class_name = ""
#
# File ~/HypEx/hypex/experiments/base.py:200, in Experiment.execute(self, data)
#     198         cur_executor = self._get_executor_backend(executor, experiment_data.ds)
#     199         cur_executor.key = self.key
# --> 200         experiment_data = cur_executor.execute(experiment_data)
#     201 return experiment_data
#
# File ~/HypEx/hypex/utils/profiling.py:140, in timeit.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     138 should_profile = enabled if enabled is not None else _PROFILING_ENABLED
#     139 if not should_profile:
# --> 140     return func(*args, **kwargs)
#     142 # Determine function/method name
#     143 class_name = ""
#
# File ~/HypEx/hypex/comparators/abstract.py:995, in StatsComparator.execute(self, data)
#     989     # The target columns for aggregation include both original and
#     990     # matched variants so that _inner_function can compare them.
#     991     matched_target_cols = target_cols + [
#     992         f"{c}_matched" for c in target_cols
#     993     ]
# --> 995     group_col_stats = self._compute_stats(
#     996         data=prepared_data,
#     997         group_cols=[group_col],
#     998         target_columns=matched_target_cols,
#     999         grouped=None,
#    1000         stats=self.stats,
#    1001     )
#    1002 else:
#    1003     raise ValueError(
#    1004         f"StatsComparator supports 'groups' and 'matched_pairs' only, "
#    1005         f"got compare_by={self.compare_by!r}"
#    1006     )
#
# File ~/HypEx/hypex/utils/profiling.py:140, in timeit.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     138 should_profile = enabled if enabled is not None else _PROFILING_ENABLED
#     139 if not should_profile:
# --> 140     return func(*args, **kwargs)
#     142 # Determine function/method name
#     143 class_name = ""
#
# File ~/HypEx/hypex/comparators/abstract.py:707, in StatsComparator._compute_stats(cls, data, group_cols, target_columns, stats, **kwargs)
#     705 stats = stats or cls.REQUIRED_STATS
#     706 ext = StatsAggregationExtension()
# --> 707 return ext.calc(
#     708     data=data,
#     709     group_cols=group_cols,
#     710     target_cols=target_columns,
#     711     stats=stats,
#     712 )
#
# File ~/HypEx/hypex/extensions/stats_hypothesis_testing.py:47, in StatsAggregationExtension.calc(self, data, group_cols, target_cols, stats, **kwargs)
#      44 from ..utils import BackendsEnum
#      46 if data.backend_type == BackendsEnum.spark:
# ---> 47     return self._calc_spark(
#      48         data=data,
#      49         group_cols=group_cols,
#      50         target_cols=target_cols,
#      51         stats=stats,
#      52         **kwargs,
#      53     )
#      54 else:
#      55     return self._calc_pandas(
#      56         data=data,
#      57         group_cols=group_cols,
#    (...)     60         **kwargs,
#      61     )
#
# File ~/HypEx/hypex/utils/profiling.py:140, in timeit.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     138 should_profile = enabled if enabled is not None else _PROFILING_ENABLED
#     139 if not should_profile:
# --> 140     return func(*args, **kwargs)
#     142 # Determine function/method name
#     143 class_name = ""
#
# File ~/HypEx/hypex/extensions/stats_hypothesis_testing.py:171, in StatsAggregationExtension._calc_spark(self, data, group_cols, target_cols, stats, **kwargs)
#     168             agg_exprs.append(F.max(col_ref).alias(alias))
#     170 group_col_refs = [safe_col(c) for c in group_cols]
# --> 171 agg_sdf = sdf.groupBy(*group_col_refs).agg(*agg_exprs)
#     172 rows = agg_sdf.collect()
#     174 result = {}
#
# File ~/HypEx/.venv/lib/python3.11/site-packages/pyspark/sql/group.py:179, in GroupedData.agg(self, *exprs)
#      89 def agg(self, *exprs: Union[Column, Dict[str, str]]) -> DataFrame:
#      90     """Compute aggregates and returns the result as a :class:`DataFrame`.
#      91
#      92     The available aggregate functions can be:
#    (...)    177     +-----+------------+
#     178     """
# --> 179     assert exprs, "exprs should not be empty"
#     180     if len(exprs) == 1 and isinstance(exprs[0], dict):
#     181         jdf = self._jgd.agg(exprs[0])
#
# AssertionError: exprs should not be empty
# 26/08/28 13:12:03 WARN HeartbeatReceiver: Removing executor 1 with no recent heartbeats: 227586 ms exceeds timeout 120000 ms
# 26/08/28 13:12:03 WARN Master: Removing worker-20260827125633-192.168.1.64-49666 because we got no heartbeat in 60 seconds
# 26/08/28 13:12:03 WARN Master: Removing worker-20260827125633-192.168.1.64-49664 because we got no heartbeat in 60 seconds
# 26/08/28 13:12:03 WARN Master: App app-20260827125634-0000 requires more resource than any of Workers could have.
# 26/08/28 13:12:06 WARN TransportChannelHandler: Exception in connection from /192.168.1.64:49654
# java.io.IOException: Can't assign requested address
# 	at java.base/sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at java.base/sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at java.base/sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:276)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:233)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:223)
# 	at java.base/sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:356)
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:254)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# 26/08/28 13:12:06 WARN TransportChannelHandler: Exception in connection from /192.168.1.64:49654
# java.io.IOException: Can't assign requested address
# 	at java.base/sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at java.base/sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at java.base/sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:276)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:233)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:223)
# 	at java.base/sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:356)
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:254)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# 26/08/28 13:12:06 ERROR Worker: Connection to master failed! Waiting for master to reconnect...
# 26/08/28 13:12:06 ERROR Worker: Connection to master failed! Waiting for master to reconnect...
# 26/08/28 13:12:06 ERROR Worker: Connection to master failed! Waiting for master to reconnect...
# 26/08/28 13:12:06 ERROR Worker: Connection to master failed! Waiting for master to reconnect...
# 26/08/28 13:12:09 ERROR TransportClient: Failed to send RPC RPC 8386436812054778552 to /192.168.1.64:49654: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 26/08/28 13:12:09 ERROR Worker: Failed to send ExecutorStateChanged(app-20260827125634-0000,1,EXITED,Some(Command exited with code 0),Some(0)) to Master NettyRpcEndpointRef(spark://Master@192.168.1.64:49654), will retry (1/5).
# java.io.IOException: Failed to send RPC RPC 8386436812054778552 to /192.168.1.64:49654: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 26/08/28 13:12:10 ERROR TransportClient: Failed to send RPC RPC 4651150650744951232 to /192.168.1.64:49654: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 26/08/28 13:12:10 ERROR Worker: Failed to send ExecutorStateChanged(app-20260827125634-0000,0,EXITED,Some(Command exited with code 0),Some(0)) to Master NettyRpcEndpointRef(spark://Master@192.168.1.64:49654), will retry (1/5).
# java.io.IOException: Failed to send RPC RPC 4651150650744951232 to /192.168.1.64:49654: io.netty.channel.StacklessClosedChannelException
# 	at org.apache.spark.network.client.TransportClient$RpcChannelListener.handleFailure(TransportClient.java:395)
# 	at org.apache.spark.network.client.TransportClient$StdChannelListener.operationComplete(TransportClient.java:372)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListener0(DefaultPromise.java:590)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListenersNow(DefaultPromise.java:557)
# 	at io.netty.util.concurrent.DefaultPromise.notifyListeners(DefaultPromise.java:492)
# 	at io.netty.util.concurrent.DefaultPromise.setValue0(DefaultPromise.java:636)
# 	at io.netty.util.concurrent.DefaultPromise.setFailure0(DefaultPromise.java:629)
# 	at io.netty.util.concurrent.DefaultPromise.tryFailure(DefaultPromise.java:118)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.safeSetFailure(AbstractChannel.java:999)
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(AbstractChannel.java:860)
# 	at io.netty.channel.DefaultChannelPipeline$HeadContext.write(DefaultChannelPipeline.java:1367)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWrite0(AbstractChannelHandlerContext.java:877)
# 	at io.netty.channel.AbstractChannelHandlerContext.invokeWriteAndFlush(AbstractChannelHandlerContext.java:940)
# 	at io.netty.channel.AbstractChannelHandlerContext$WriteTask.run(AbstractChannelHandlerContext.java:1247)
# 	at io.netty.util.concurrent.AbstractEventExecutor.runTask(AbstractEventExecutor.java:174)
# 	at io.netty.util.concurrent.AbstractEventExecutor.safeExecute(AbstractEventExecutor.java:167)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor.runAllTasks(SingleThreadEventExecutor.java:470)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:569)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 26/08/28 13:12:21 WARN TransportChannelHandler: Exception in connection from /192.168.1.64:49654
# java.io.IOException: Can't assign requested address
# 	at java.base/sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at java.base/sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at java.base/sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:276)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:233)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:223)
# 	at java.base/sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:356)
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:254)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# 26/08/28 13:12:21 ERROR TransportResponseHandler: Still have 1 requests outstanding when connection from /192.168.1.64:49654 is closed
# 26/08/28 13:12:21 WARN StandaloneAppClient$ClientEndpoint: Could not connect to 192.168.1.64:49654: java.io.IOException: Can't assign requested address
# 26/08/28 13:12:21 WARN StandaloneAppClient$ClientEndpoint: Could not connect to 192.168.1.64:49654: java.io.IOException: Can't assign requested address
# 26/08/28 13:12:21 WARN StandaloneAppClient$ClientEndpoint: Connection to 192.168.1.64:49654 failed; waiting for master to reconnect...
# 26/08/28 13:12:21 WARN StandaloneSchedulerBackend: Disconnected from Spark cluster! Waiting for reconnection...
# 26/08/28 13:12:21 WARN StandaloneAppClient$ClientEndpoint: Connection to 192.168.1.64:49654 failed; waiting for master to reconnect...
# 26/08/28 13:12:21 ERROR Utils: Uncaught exception in thread kill-executor-thread
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.scheduler.cluster.CoarseGrainedSchedulerBackend.killExecutors(CoarseGrainedSchedulerBackend.scala:981)
# 	at org.apache.spark.SparkContext.killAndReplaceExecutor(SparkContext.scala:1974)
# 	at org.apache.spark.HeartbeatReceiver$$anon$2.$anonfun$run$2(HeartbeatReceiver.scala:214)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.HeartbeatReceiver$$anon$2.run(HeartbeatReceiver.scala:211)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:264)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: java.io.IOException: Can't assign requested address
# 	at java.base/sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at java.base/sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at java.base/sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:276)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:233)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:223)
# 	at java.base/sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:356)
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:254)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	... 1 more
# 26/08/28 13:12:21 WARN TransportChannelHandler: Exception in connection from /192.168.1.64:49670
# java.io.IOException: Can't assign requested address
# 	at java.base/sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at java.base/sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at java.base/sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:276)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:233)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:223)
# 	at java.base/sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:356)
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:254)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788)
# ...
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# 26/08/28 14:06:32 ERROR Worker: All masters are unresponsive! Giving up.
# 26/08/28 14:06:32 ERROR TransportClient: Failed to send RPC RPC 6331213337548463272 to /192.168.1.64:49654: io.netty.channel.StacklessClosedChannelException
# io.netty.channel.StacklessClosedChannelException
# 	at io.netty.channel.AbstractChannel$AbstractUnsafe.write(Object, ChannelPromise)(Unknown Source)
# 26/08/28 14:06:32 WARN Worker: Failed to connect to master 192.168.1.64:49654
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.deploy.worker.Worker$$anon$2.run(Worker.scala:370)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:264)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Message is dropped because Outbox is stopped
# 	at org.apache.spark.rpc.netty.Outbox.stop(Outbox.scala:279)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.cleanup(NettyRpcEnv.scala:325)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.shutdown(NettyRpcEnv.scala:309)
# 	at org.apache.spark.deploy.LocalSparkCluster.$anonfun$stop$2(LocalSparkCluster.scala:95)
# 	at org.apache.spark.deploy.LocalSparkCluster.$anonfun$stop$2$adapted(LocalSparkCluster.scala:95)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.deploy.LocalSparkCluster.stop(LocalSparkCluster.scala:95)
# 	at org.apache.spark.SparkContext$.$anonfun$createTaskScheduler$2(SparkContext.scala:3192)
# 	at org.apache.spark.SparkContext$.$anonfun$createTaskScheduler$2$adapted(SparkContext.scala:3191)
# 	at org.apache.spark.scheduler.cluster.StandaloneSchedulerBackend.org$apache$spark$scheduler$cluster$StandaloneSchedulerBackend$$stop(StandaloneSchedulerBackend.scala:279)
# 	at org.apache.spark.scheduler.cluster.StandaloneSchedulerBackend.stop(StandaloneSchedulerBackend.scala:142)
# 	at org.apache.spark.scheduler.SchedulerBackend.stop(SchedulerBackend.scala:33)
# 	at org.apache.spark.scheduler.SchedulerBackend.stop$(SchedulerBackend.scala:33)
# 	at org.apache.spark.scheduler.cluster.CoarseGrainedSchedulerBackend.stop(CoarseGrainedSchedulerBackend.scala:54)
# 	at org.apache.spark.scheduler.TaskSchedulerImpl.$anonfun$stop$2(TaskSchedulerImpl.scala:992)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.scheduler.TaskSchedulerImpl.stop(TaskSchedulerImpl.scala:992)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$stop$4(DAGScheduler.scala:2976)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.scheduler.DAGScheduler.stop(DAGScheduler.scala:2976)
# 	at org.apache.spark.SparkContext.$anonfun$stop$12(SparkContext.scala:2263)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.SparkContext.stop(SparkContext.scala:2263)
# 	at org.apache.spark.SparkContext.stop(SparkContext.scala:2216)
# 	at org.apache.spark.SparkContext.$anonfun$new$34(SparkContext.scala:686)
# 	at org.apache.spark.util.SparkShutdownHook.run(ShutdownHookManager.scala:214)
# 	at org.apache.spark.util.SparkShutdownHookManager.$anonfun$runAll$2(ShutdownHookManager.scala:188)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.util.SparkShutdownHookManager.$anonfun$runAll$1(ShutdownHookManager.scala:188)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.util.SparkShutdownHookManager.runAll(ShutdownHookManager.scala:188)
# 	at org.apache.spark.util.SparkShutdownHookManager$$anon$2.run(ShutdownHookManager.scala:178)
# 	... 5 more
# 26/08/28 14:06:32 WARN Worker: Failed to connect to master 192.168.1.64:49654
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.deploy.worker.Worker$$anon$2.run(Worker.scala:370)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:264)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Message is dropped because Outbox is stopped
# 	at org.apache.spark.rpc.netty.Outbox.stop(Outbox.scala:279)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.cleanup(NettyRpcEnv.scala:325)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.shutdown(NettyRpcEnv.scala:309)
# 	at org.apache.spark.deploy.LocalSparkCluster.$anonfun$stop$2(LocalSparkCluster.scala:95)
# 	at org.apache.spark.deploy.LocalSparkCluster.$anonfun$stop$2$adapted(LocalSparkCluster.scala:95)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.deploy.LocalSparkCluster.stop(LocalSparkCluster.scala:95)
# 	at org.apache.spark.SparkContext$.$anonfun$createTaskScheduler$2(SparkContext.scala:3192)
# 	at org.apache.spark.SparkContext$.$anonfun$createTaskScheduler$2$adapted(SparkContext.scala:3191)
# 	at org.apache.spark.scheduler.cluster.StandaloneSchedulerBackend.org$apache$spark$scheduler$cluster$StandaloneSchedulerBackend$$stop(StandaloneSchedulerBackend.scala:279)
# 	at org.apache.spark.scheduler.cluster.StandaloneSchedulerBackend.stop(StandaloneSchedulerBackend.scala:142)
# 	at org.apache.spark.scheduler.SchedulerBackend.stop(SchedulerBackend.scala:33)
# 	at org.apache.spark.scheduler.SchedulerBackend.stop$(SchedulerBackend.scala:33)
# 	at org.apache.spark.scheduler.cluster.CoarseGrainedSchedulerBackend.stop(CoarseGrainedSchedulerBackend.scala:54)
# 	at org.apache.spark.scheduler.TaskSchedulerImpl.$anonfun$stop$2(TaskSchedulerImpl.scala:992)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.scheduler.TaskSchedulerImpl.stop(TaskSchedulerImpl.scala:992)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$stop$4(DAGScheduler.scala:2976)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.scheduler.DAGScheduler.stop(DAGScheduler.scala:2976)
# 	at org.apache.spark.SparkContext.$anonfun$stop$12(SparkContext.scala:2263)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.SparkContext.stop(SparkContext.scala:2263)
# 	at org.apache.spark.SparkContext.stop(SparkContext.scala:2216)
# 	at org.apache.spark.SparkContext.$anonfun$new$34(SparkContext.scala:686)
# 	at org.apache.spark.util.SparkShutdownHook.run(ShutdownHookManager.scala:214)
# 	at org.apache.spark.util.SparkShutdownHookManager.$anonfun$runAll$2(ShutdownHookManager.scala:188)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.util.SparkShutdownHookManager.$anonfun$runAll$1(ShutdownHookManager.scala:188)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.util.SparkShutdownHookManager.runAll(ShutdownHookManager.scala:188)
# 	at org.apache.spark.util.SparkShutdownHookManager$$anon$2.run(ShutdownHookManager.scala:178)
# 	... 5 more
# 26/08/28 14:06:50 WARN TransportChannelHandler: Exception in connection from /192.168.1.64:49676
# java.io.IOException: Can't assign requested address
# 	at java.base/sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at java.base/sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at java.base/sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:276)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:233)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:223)
# 	at java.base/sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:356)
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:254)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# 26/08/28 14:06:50 WARN TransportChannelHandler: Exception in connection from /192.168.1.64:49677
# java.io.IOException: Can't assign requested address
# 	at java.base/sun.nio.ch.FileDispatcherImpl.read0(Native Method)
# 	at java.base/sun.nio.ch.SocketDispatcher.read(SocketDispatcher.java:39)
# 	at java.base/sun.nio.ch.IOUtil.readIntoNativeBuffer(IOUtil.java:276)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:233)
# 	at java.base/sun.nio.ch.IOUtil.read(IOUtil.java:223)
# 	at java.base/sun.nio.ch.SocketChannelImpl.read(SocketChannelImpl.java:356)
# 	at io.netty.buffer.PooledByteBuf.setBytes(PooledByteBuf.java:254)
# 	at io.netty.buffer.AbstractByteBuf.writeBytes(AbstractByteBuf.java:1132)
# 	at io.netty.channel.socket.nio.NioSocketChannel.doReadBytes(NioSocketChannel.java:357)
# 	at io.netty.channel.nio.AbstractNioByteChannel$NioByteUnsafe.read(AbstractNioByteChannel.java:151)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKey(NioEventLoop.java:788)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeysOptimized(NioEventLoop.java:724)
# 	at io.netty.channel.nio.NioEventLoop.processSelectedKeys(NioEventLoop.java:650)
# 	at io.netty.channel.nio.NioEventLoop.run(NioEventLoop.java:562)
# 	at io.netty.util.concurrent.SingleThreadEventExecutor$4.run(SingleThreadEventExecutor.java:997)
# 	at io.netty.util.internal.ThreadExecutorMap$2.run(ThreadExecutorMap.java:74)
# 	at io.netty.util.concurrent.FastThreadLocalRunnable.run(FastThreadLocalRunnable.java:30)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# 26/08/28 14:07:02 WARN ShutdownHookManager: ShutdownHook '' timeout, java.util.concurrent.TimeoutException
# java.util.concurrent.TimeoutException
# 	at java.base/java.util.concurrent.FutureTask.get(FutureTask.java:204)
# 	at org.apache.hadoop.util.ShutdownHookManager.executeShutdown(ShutdownHookManager.java:124)
# 	at org.apache.hadoop.util.ShutdownHookManager$1.run(ShutdownHookManager.java:95)
# 26/08/28 14:07:02 WARN SparkContext: Ignoring Exception while stopping SparkContext from shutdown hook
# java.lang.InterruptedException
# 	at java.base/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.reportInterruptAfterWait(AbstractQueuedSynchronizer.java:2056)
# 	at java.base/java.util.concurrent.locks.AbstractQueuedSynchronizer$ConditionObject.awaitNanos(AbstractQueuedSynchronizer.java:2133)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.awaitTermination(ThreadPoolExecutor.java:1454)
# 	at org.apache.spark.rpc.netty.MessageLoop.stop(MessageLoop.scala:60)
# 	at org.apache.spark.rpc.netty.Dispatcher.stop(Dispatcher.scala:205)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.cleanup(NettyRpcEnv.scala:331)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.shutdown(NettyRpcEnv.scala:309)
# 	at org.apache.spark.deploy.LocalSparkCluster.$anonfun$stop$2(LocalSparkCluster.scala:95)
# 	at org.apache.spark.deploy.LocalSparkCluster.$anonfun$stop$2$adapted(LocalSparkCluster.scala:95)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.deploy.LocalSparkCluster.stop(LocalSparkCluster.scala:95)
# 	at org.apache.spark.SparkContext$.$anonfun$createTaskScheduler$2(SparkContext.scala:3192)
# 	at org.apache.spark.SparkContext$.$anonfun$createTaskScheduler$2$adapted(SparkContext.scala:3191)
# 	at org.apache.spark.scheduler.cluster.StandaloneSchedulerBackend.org$apache$spark$scheduler$cluster$StandaloneSchedulerBackend$$stop(StandaloneSchedulerBackend.scala:279)
# 	at org.apache.spark.scheduler.cluster.StandaloneSchedulerBackend.stop(StandaloneSchedulerBackend.scala:142)
# 	at org.apache.spark.scheduler.SchedulerBackend.stop(SchedulerBackend.scala:33)
# 	at org.apache.spark.scheduler.SchedulerBackend.stop$(SchedulerBackend.scala:33)
# 	at org.apache.spark.scheduler.cluster.CoarseGrainedSchedulerBackend.stop(CoarseGrainedSchedulerBackend.scala:54)
# 	at org.apache.spark.scheduler.TaskSchedulerImpl.$anonfun$stop$2(TaskSchedulerImpl.scala:992)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.scheduler.TaskSchedulerImpl.stop(TaskSchedulerImpl.scala:992)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$stop$4(DAGScheduler.scala:2976)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.scheduler.DAGScheduler.stop(DAGScheduler.scala:2976)
# 	at org.apache.spark.SparkContext.$anonfun$stop$12(SparkContext.scala:2263)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.SparkContext.stop(SparkContext.scala:2263)
# 	at org.apache.spark.SparkContext.stop(SparkContext.scala:2216)
# 	at org.apache.spark.SparkContext.$anonfun$new$34(SparkContext.scala:686)
# 	at org.apache.spark.util.SparkShutdownHook.run(ShutdownHookManager.scala:214)
# 	at org.apache.spark.util.SparkShutdownHookManager.$anonfun$runAll$2(ShutdownHookManager.scala:188)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.util.SparkShutdownHookManager.$anonfun$runAll$1(ShutdownHookManager.scala:188)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.util.SparkShutdownHookManager.runAll(ShutdownHookManager.scala:188)
# 	at org.apache.spark.util.SparkShutdownHookManager$$anon$2.run(ShutdownHookManager.scala:178)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:264)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)

# %%
result.resume
# Out:
#      Effect Size  Standard Error  P-value  CI Lower  CI Upper      outcome
# ATT         0.00            0.01     0.89     -0.02      0.03  post_spends
# ATC         0.01            0.01     0.37     -0.01      0.03  post_spends
# ATE         0.01            0.01     0.56     -0.01      0.03  post_spends

# %% [markdown]
# ### ATT — Average Treatment effect on the Treated
#
# $
# ATT = E[Y(1) - Y(0) \mid T=1]
# $
#  - shows **how the treatment affected those who actually received it**.
#
# ### ATC — Average Treatment effect on the Controls
#
# $
# ATC = E[Y(1) - Y(0) \mid T=0]
# $
#  - shows **what would have happened to the control group if they had received the treatment**.
#
# ### ATE — Average Treatment Effect
#
# $
# ATE = E[Y(1) - Y(0)]
# $
# - the overall average effect in the population — a combination of ATT and ATC, weighted by group sizes.

# %%
result.indexes
# Out:
#       indexes_0
# 0          2744
# 1          5529
# 2          5628
# 3           582
# 4          2247
# ...         ...
# 9995        386
# 9996       4685
# 9997       3842
# 9998       5548
# 9999       2325
#
# [10000 rows x 1 columns]

# %%
result.full_data
# Out:
#       user_id  signup_month  treat  pre_spends  post_spends   age gender  \
# 0           0             0      0       475.0   475.696965  23.0      M
# 1           1            11      1       487.0   487.535208  51.0      F
# 2           2             0      0       484.0   484.320639  35.0      M
# 3           3            11      1       494.5   495.159047  29.0      M
# 4           4             0      0       455.5   455.675909  53.0      M
# ...       ...           ...    ...         ...          ...   ...    ...
# 9995     9995             5      1       487.5   487.741243  31.0      M
# 9996     9996            11      1       453.5   454.099548  41.0      M
# 9997     9997            10      1       482.0   482.308959  58.0      F
# 9998     9998             6      1       477.0   477.867590  41.0      F
# 9999     9999             0      0       496.0   496.367291  18.0      M
#
#         industry  user_id_matched_0  signup_month_matched_0  treat_matched_0  \
# 0     E-commerce               2744                      11                1
# 1      Logistics               5529                       0                0
# 2     E-commerce               5628                       5                1
# 3      Logistics                582                       0                0
# 4     E-commerce               2247                      11                1
# ...          ...                ...                     ...              ...
# 9995   Logistics                386                       0                0
# 9996  E-commerce               4685                       0                0
# 9997   Logistics               3842                       0                0
# 9998  E-commerce               5548                       0                0
# 9999  E-commerce               2325                       8                1
#
#       pre_spends_matched_0  post_spends_matched_0  age_matched_0  \
# 0                    475.0             475.896827           23.0
# 1                    486.5             487.441640           51.0
# 2                    484.5             485.391149           34.0
# 3                    494.5             494.877988           29.0
# 4                    455.5             455.833920           54.0
# ...                    ...                    ...            ...
# 9995                 487.0             487.204044           31.0
# 9996                 454.0             454.738503           45.0
# 9997                 481.5             481.902546           57.0
# 9998                 478.5             479.044356           41.0
# 9999                 495.0             495.622851           19.0
#
#      gender_matched_0 industry_matched_0
# 0                   M         E-commerce
# 1                   F          Logistics
# 2                   M         E-commerce
# 3                   M          Logistics
# 4                   M         E-commerce
# ...               ...                ...
# 9995                M          Logistics
# 9996                M         E-commerce
# 9997                F          Logistics
# 9998                F         E-commerce
# 9999                M         E-commerce
#
# [10000 rows x 16 columns]

# %% [markdown]
# ## Distances: `distance="mahalanobis"` or `"l2"`
#
# ### 🔸 Euclidean (L2)
#
# This is the classic metric:
# $ d(x_i, x_j) = \sqrt{\sum_k (x_{ik} - x_{jk})^2} $
# Simply measures the "geometric" distance between points in feature space.
#
# ### 🔸 Mahalanobis distance
#
# A more advanced metric:
# $ d_M(x_i, x_j) = \sqrt{(x_i - x_j)^T \Sigma^{-1} (x_i - x_j)} $
# where $\Sigma$ is the covariance matrix of features.
# This metric accounts for the scale and correlation of features, making the comparison more accurate:

# %%
test = Matching(distance='l2')
result = test.execute(data)

# %%
result.resume
# Out:
#      Effect Size  Standard Error  P-value  CI Lower  CI Upper      outcome
# ATT         0.01            0.01     0.60     -0.02      0.03  post_spends
# ATC         0.00            0.01     0.75     -0.02      0.03  post_spends
# ATE         0.01            0.01     0.61     -0.02      0.03  post_spends

# %%
test = Matching(distance='mahalanobis')
result = test.execute(data)

# %%
result.resume
# Out:
#      Effect Size  Standard Error  P-value  CI Lower  CI Upper      outcome
# ATT         0.00            0.01     0.89     -0.02      0.03  post_spends
# ATC         0.01            0.01     0.37     -0.01      0.03  post_spends
# ATE         0.01            0.01     0.56     -0.01      0.03  post_spends

# %% [markdown]
# # `group_match`: matching by groups
#
# The parameter `group_match=True` forces HypEx to aggregate observations into groups (by a specified identifier), and then search for pairs between groups rather than individual objects.
# This reduces variability at the individual level and allows for effect estimation at more aggregated levels.

# %%
data = Dataset(
    roles={
        "user_id": InfoRole(int),
        "treat": TreatmentRole(int),
        "post_spends": TargetRole(float),
        "gender": GroupingRole(str),
        "pre_spends": FeatureRole(float),
        "industry": FeatureRole(str),
        "age": FeatureRole(int),
    },
    data=df,
    default_role=InfoRole(),
)
data['gender'].unique()
# Out:
# {'gender': array(['M', 'F'], dtype=object)}

# %% [markdown]
# We can change **metric** and do estimation again.

# %%
test = Matching(group_match=True)
result = test.execute(data)
# Out:
# 100%|██████████| 2/2 [00:02<00:00,  1.25s/it]

# %%
result.resume
# Out:
#      F Effect Size  M Effect Size  F Standard Error  M Standard Error  \
# ATT           0.00            0.0              0.02              0.02
# ATC           0.02           -0.0              0.02              0.02
# ATE           0.01           -0.0              0.01              0.01
#
#      F P-value  M P-value  F CI Lower  M CI Lower  F CI Upper  M CI Upper  \
# ATT       0.80       0.99       -0.03       -0.03        0.04        0.03
# ATC       0.31       0.81       -0.01       -0.04        0.05        0.03
# ATE       0.47       0.90       -0.02       -0.03        0.04        0.03
#
#          outcome
# ATT  post_spends
# ATC  post_spends
# ATE  post_spends

# %% [markdown]
# # `bias_estimation`: bias estimation and correction
#
# When `bias_estimation=True`, HypEx:
#
# 1. **Estimates residual imbalance** across all features after matching (e.g., using standardized mean difference, t-tests, etc.);
# 2. **Corrects the final effect estimate** to reduce the impact of remaining bias.

# %%
data = Dataset(
    roles={
        "user_id": InfoRole(int),
        "treat": TreatmentRole(int),
        "post_spends": TargetRole(float),
        "gender": FeatureRole(str),
        "pre_spends": FeatureRole(float),
        "industry": FeatureRole(str),
        "age": FeatureRole(int),
    },
    data=df,
    default_role=InfoRole(),
)

# %%
test = Matching(bias_estimation=False)
result = test.execute(data)

# %%
result.resume
# Out:
#      Effect Size  Standard Error  P-value  CI Lower  CI Upper      outcome
# ATT         0.65            0.06     0.00      0.53      0.76  post_spends
# ATC         0.06            0.09     0.52     -0.12      0.23  post_spends
# ATE         0.35            0.07     0.00      0.22      0.48  post_spends

# %% [markdown]
# # `quality_tests`: matching quality checks
#
# Main tests:
#
# * `'ks-test'` — Kolmogorov–Smirnov test for comparing distributions;
# * `'t-test'` — test for equality of means;
# * `'chi2-test'` — test for independence of categorical features;
#
# These tests help understand whether balance was achieved and how reliable the result can be considered.

# %%
test = Matching(quality_tests=['chi2-test', 'ks-test', 't-test'])
result = test.execute(data)

# %%
result.resume
# Out:
#      Effect Size  Standard Error  P-value  CI Lower  CI Upper      outcome
# ATT         0.00            0.01     0.89     -0.02      0.03  post_spends
# ATC         0.01            0.01     0.37     -0.01      0.03  post_spends
# ATE         0.01            0.01     0.56     -0.01      0.03  post_spends

# %%
result.quality_results
# Out:
#       feature         group TTest pass  TTest p-value KSTest pass  \
# 0  pre_spends  0┆pre_spends         OK       0.879358          OK
# 1  pre_spends  1┆pre_spends         OK       0.109933          OK
# 2         age         0┆age         OK       0.946168          OK
# 3         age         1┆age         OK       0.869023          OK
# 4      gender      0┆gender        NaN            NaN         NaN
# 5      gender      1┆gender        NaN            NaN         NaN
# 6    industry    0┆industry        NaN            NaN         NaN
# 7    industry    1┆industry        NaN            NaN         NaN
#
#    KSTest p-value Chi2Test pass  Chi2Test p-value
# 0        0.999905           NaN               NaN
# 1        0.093432           NaN               NaN
# 2        1.000000           NaN               NaN
# 3        0.975792           NaN               NaN
# 4             NaN            OK               1.0
# 5             NaN            OK               1.0
# 6             NaN            OK               1.0
# 7             NaN            OK               1.0

# %% [markdown]
# # `faiss_mode`: search acceleration
#
# FAISS is a high-performance library for nearest neighbor search, developed by Meta AI.
# HypEx uses it for finding pairs in large datasets.
#
# Modes:
#
# * `'base'` — exact but slow search;
# * `'fast'` — approximate but fast (uses indexing);
# * `'auto'` — HypEx automatically chooses the optimal option depending on data size.

# %%
test = Matching(faiss_mode="base")
result = test.execute(data)
result.resume
# Out:
#      Effect Size  Standard Error  P-value  CI Lower  CI Upper      outcome
# ATT         0.00            0.01     0.89     -0.02      0.03  post_spends
# ATC         0.01            0.01     0.37     -0.01      0.03  post_spends
# ATE         0.01            0.01     0.56     -0.01      0.03  post_spends

# %% [markdown]
# Finally, we may search pairs in L2 distance.

# %%
test = Matching(faiss_mode="fast")
result = test.execute(data)
result.resume
# Out:
# WARNING clustering 4981 points to 1000 centroids: please provide at least 39000 training points
# WARNING clustering 5019 points to 1000 centroids: please provide at least 39000 training points
#      Effect Size  Standard Error  P-value  CI Lower  CI Upper      outcome
# ATT         0.00            0.01     0.93     -0.02      0.03  post_spends
# ATC         0.01            0.01     0.41     -0.01      0.03  post_spends
# ATE         0.01            0.01     0.61     -0.01      0.03  post_spends

# %% [markdown]
# # `n_neighbors`: number of neighbors
#
# Determines how many control objects will be matched for each object from the treatment group.
#
# * `n_neighbors=1` — classic **one-to-one matching**;
# * `n_neighbors>1` — **one-to-many matching**, when one treated object corresponds to multiple control objects.

# %%
test = Matching(n_neighbors=3)
result = test.execute(data)
result.resume
# Out:
# /home/tony_montana/job/HypEx/hypex/comparators/abstract.py:196: UserWarning: baseline_field_data must have only one column when the comparison is done by matched_pairs. 3 passed. FaissNearestNeighbors┴┴┴0 will be used.
#   warnings.warn(
# /home/tony_montana/job/HypEx/hypex/comparators/abstract.py:196: UserWarning: baseline_field_data must have only one column when the comparison is done by matched_pairs. 3 passed. FaissNearestNeighbors┴┴┴0 will be used.
#   warnings.warn(
# /home/tony_montana/job/HypEx/hypex/comparators/abstract.py:196: UserWarning: baseline_field_data must have only one column when the comparison is done by matched_pairs. 3 passed. FaissNearestNeighbors┴┴┴0 will be used.
#   warnings.warn(
# /home/tony_montana/job/HypEx/hypex/comparators/abstract.py:196: UserWarning: baseline_field_data must have only one column when the comparison is done by matched_pairs. 3 passed. FaissNearestNeighbors┴┴┴0 will be used.
#   warnings.warn(
# /home/tony_montana/job/HypEx/hypex/comparators/abstract.py:196: UserWarning: baseline_field_data must have only one column when the comparison is done by matched_pairs. 3 passed. FaissNearestNeighbors┴┴┴0 will be used.
#   warnings.warn(
# /home/tony_montana/job/HypEx/hypex/comparators/abstract.py:196: UserWarning: baseline_field_data must have only one column when the comparison is done by matched_pairs. 3 passed. FaissNearestNeighbors┴┴┴0 will be used.
#   warnings.warn(
#      Effect Size  Standard Error  P-value  CI Lower  CI Upper      outcome
# ATT         -0.0            0.01     0.64     -0.02      0.01  post_spends
# ATC          0.0            0.01     0.85     -0.01      0.02  post_spends
# ATE         -0.0            0.01     0.87     -0.02      0.01  post_spends

# %%
result.indexes
# Out:
#       indexes_0  indexes_1  indexes_2
# 0          2744       2487       3192
# 1          5529       2706       8209
# 2          5628       6447       6387
# 3           582       6814       2530
# 4          2247       6796       3579
# ...         ...        ...        ...
# 9995        386       4266       1673
# 9996       4685       4805       7295
# 9997       3842        286       5800
# 9998       5548       1259       3453
# 9999       2325       8676        436
#
# [10000 rows x 3 columns]

# %%
result.full_data
# Out:
#       user_id  signup_month  treat  pre_spends  post_spends   age gender  \
# 0           0             0      0       475.0   475.696965  23.0      M
# 1           1            11      1       487.0   487.535208  51.0      F
# 2           2             0      0       484.0   484.320639  35.0      M
# 3           3            11      1       494.5   495.159047  29.0      M
# 4           4             0      0       455.5   455.675909  53.0      M
# ...       ...           ...    ...         ...          ...   ...    ...
# 9995     9995             5      1       487.5   487.741243  31.0      M
# 9996     9996            11      1       453.5   454.099548  41.0      M
# 9997     9997            10      1       482.0   482.308959  58.0      F
# 9998     9998             6      1       477.0   477.867590  41.0      F
# 9999     9999             0      0       496.0   496.367291  18.0      M
#
#         industry  user_id_matched_0  signup_month_matched_0  ...  \
# 0     E-commerce               2744                      11  ...
# 1      Logistics               5529                       0  ...
# 2     E-commerce               5628                       5  ...
# 3      Logistics                582                       0  ...
# 4     E-commerce               2247                      11  ...
# ...          ...                ...                     ...  ...
# 9995   Logistics                386                       0  ...
# 9996  E-commerce               4685                       0  ...
# 9997   Logistics               3842                       0  ...
# 9998  E-commerce               5548                       0  ...
# 9999  E-commerce               2325                       8  ...
#
#       gender_matched_1  industry_matched_1  user_id_matched_2  \
# 0                    M          E-commerce               2744
# 1                    F           Logistics               5529
# 2                    M          E-commerce               5628
# 3                    M           Logistics                582
# 4                    M          E-commerce               2247
# ...                ...                 ...                ...
# 9995                 M           Logistics                386
# 9996                 M          E-commerce               4685
# 9997                 F           Logistics               3842
# 9998                 F          E-commerce               5548
# 9999                 M          E-commerce               2325
#
#       signup_month_matched_2 treat_matched_2 pre_spends_matched_2  \
# 0                         11               1                475.0
# 1                          0               0                486.5
# 2                          5               1                484.5
# 3                          0               0                494.5
# 4                         11               1                455.5
# ...                      ...             ...                  ...
# 9995                       0               0                487.0
# 9996                       0               0                454.0
# 9997                       0               0                481.5
# 9998                       0               0                478.5
# 9999                       8               1                495.0
#
#       post_spends_matched_2  age_matched_2  gender_matched_2  \
# 0                475.896827           23.0                 M
# 1                487.441640           51.0                 F
# 2                485.391149           34.0                 M
# 3                494.877988           29.0                 M
# 4                455.833920           54.0                 M
# ...                     ...            ...               ...
# 9995             487.204044           31.0                 M
# 9996             454.738503           45.0                 M
# 9997             481.902546           57.0                 F
# 9998             479.044356           41.0                 F
# 9999             495.622851           19.0                 M
#
#       industry_matched_2
# 0             E-commerce
# 1              Logistics
# 2             E-commerce
# 3              Logistics
# 4             E-commerce
# ...                  ...
# 9995           Logistics
# 9996          E-commerce
# 9997           Logistics
# 9998          E-commerce
# 9999          E-commerce
#
# [10000 rows x 32 columns]

# %% [markdown]
# # `weights`: feature weights
#
# Not all features may be equally important for matching pairs.
# The `weights` parameter allows you to explicitly set priorities for features.

# %%
test = Matching(weights={"gender": 0.2, "industry": 0.3, "age": 0.1, "signup_month": 0.1, "pre_spends": 0.3})
result = test.execute(data)
result.resume
# Out:
#      Effect Size  Standard Error  P-value  CI Lower  CI Upper      outcome
# ATT         0.00            0.01     0.96     -0.02      0.03  post_spends
# ATC         0.01            0.01     0.50     -0.01      0.03  post_spends
# ATE         0.00            0.01     0.69     -0.02      0.02  post_spends

# %% [markdown]
# # `encode_categories`: encoding categorical features
#
# If `encode_categories=True` (default), HypEx automatically converts categorical features to numerical form (one-hot encoding).
# If False — the library expects that the user has already encoded them.
# This step is necessary so that all features can participate in distance calculations.

# %%
test = Matching(encode_categories=False)
result = test.execute(data)
result.resume
# Out:
#      Effect Size  Standard Error  P-value  CI Lower  CI Upper      outcome
# ATT        -0.00            0.01     0.98     -0.03      0.03  post_spends
# ATC         0.01            0.01     0.48     -0.02      0.03  post_spends
# ATE         0.00            0.01     0.71     -0.02      0.03  post_spends
