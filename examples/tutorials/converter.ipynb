# %% [markdown]
# ## Originals

# %%
# !poetry run jupyter nbconvert --to markdown ./AATestTutorial.ipynb
# Out:
# [NbConvertApp] Converting notebook ./AATestTutorial.ipynb to markdown
# [NbConvertApp] Writing 92802 bytes to AATestTutorial.md

# %%
# !poetry run jupyter nbconvert --to markdown ./ABTestTutorial.ipynb
# Out:
# [NbConvertApp] Converting notebook ./ABTestTutorial.ipynb to markdown
# /Users/danilsamsutdinov/HypEx/.venv/lib/python3.11/site-packages/nbformat/__init__.py:96: DuplicateCellId: Non-unique cell id '534aa48fa0686e28' detected. Corrected to '1d590e24'.
#   validate(nb)
# [NbConvertApp] Writing 23648 bytes to ABTestTutorial.md

# %% [markdown]
# ## Modified

# %% [markdown]
# !poetry run jupyter nbconvert --to markdown ./AATestTutorial_new_pandas.ipynb

# %%
# !poetry run jupyter nbconvert --to markdown ./AATestTutorial_new_pandas.ipynb
# Out:
# [NbConvertApp] Converting notebook ./AATestTutorial_new_pandas.ipynb to markdown
# [NbConvertApp] Writing 118708 bytes to AATestTutorial_new_pandas.md

# %%
# !poetry run jupyter nbconvert --to markdown ./AATestTutorial_new_spark.ipynb
# Out:
# [NbConvertApp] Converting notebook ./AATestTutorial_new_spark.ipynb to markdown
# [NbConvertApp] Writing 72737 bytes to AATestTutorial_new_spark.md

# %%
# !poetry run jupyter nbconvert --to markdown ./ABTestTutorial_new_pandas.ipynb
# Out:
# [NbConvertApp] Converting notebook ./ABTestTutorial_new_pandas.ipynb to markdown
# [NbConvertApp] Writing 48378 bytes to ABTestTutorial_new_pandas.md

# %%
# !poetry run jupyter nbconvert --to markdown ./ABTestTutorial_new_spark.ipynb
# Out:
# [NbConvertApp] Converting notebook ./ABTestTutorial_new_spark.ipynb to markdown
# [NbConvertApp] Writing 18016 bytes to ABTestTutorial_new_spark.md
