# %% [markdown]
# ## Запуск Spark-сессии (конфигурация под MAC)

# %%
import os
import time

from pyspark.sql import SparkSession

os.environ['OBJC_DISABLE_INITIALIZE_FORK_SAFETY'] = 'YES'

try:
    existing_spark = SparkSession.getActiveSession()
    if existing_spark:
        existing_spark.stop()
except:
    pass

for key in list(os.environ.keys()):
    if 'SPARK' in key or 'JAVA_OPTS' in key:
        del os.environ[key]

# --- 2. Конфигурация Кластера ---
# Формат: local-cluster[число_воркеров, ядер_на_воркер, память_на_воркер_в_МБ]
NUM_EXECUTORS = 2
CORES_PER_EXECUTOR = 6
MEMORY_PER_EXECUTOR_MB = 4096 

MASTER_URL = f"local-cluster[{NUM_EXECUTORS}, {CORES_PER_EXECUTOR}, {MEMORY_PER_EXECUTOR_MB}]"

print(f"Запуск в режиме: {MASTER_URL}")

sp_s = (SparkSession.builder
    .master(MASTER_URL)
    .appName("LocalClusterTest")
    .config("spark.driver.memory", "4g") 
    .config("spark.executor.memory", "4g")
    .config("spark.executor.cores", "6")
    .config("spark.executor.instances", NUM_EXECUTORS)
    .config("spark.memory.fraction", "0.6")
    .config("spark.sql.shuffle.partitions", "4") # Для тестов меньше дефолтных 200
    .getOrCreate()
)

sp_s.sparkContext.setLogLevel("WARN")

# --- 3. Проверка конфигурации ---
print(f"Сессия создана.")
print(f"Driver Memory Config: {sp_s.conf.get('spark.driver.memory')}")
print(f"Executor Memory Config: {sp_s.conf.get('spark.executor.memory')}")

# Проверка количества экзекуторов (может занять пару секунд на старт)
time.sleep(3) 
num_executors = len(sp_s.sparkContext.parallelize(range(10), NUM_EXECUTORS).glom().collect())
print(f"📊 Активных экзекуторов (проверка через RDD): {num_executors}")

# --- 4. Тест на распределение (Пример) ---
# Чтобы убедиться, что задача ушла на экзекуторы, а не осталась на драйвере
def print_executor_info(iterator):
    import os
    # Получаем ID экзекутора из переменных окружения процесса
    executor_id = os.environ.get('SPARK_EXECUTOR_ID', 'Driver/Local')
    process_id = os.getpid()
    return [f"Executor ID: {executor_id}, PID: {process_id}"]

# Создаем датафрейм и применяем трансформацию
df = sp_s.range(0, 10, 1, 4) # 4 партиции
result = df.rdd.mapPartitions(print_executor_info).collect()

print("\n🖥️ Где выполнялись задачи:")
for line in result:
    print(line)

sp_s
# Out:
# Запуск в режиме: local-cluster[2, 6, 4096]
# 26/05/22 09:59:51 WARN Utils: Your hostname, MacBook-Pro-Danil.local resolves to a loopback address: 127.0.0.1; using 10.246.67.107 instead (on interface en0)
# 26/05/22 09:59:51 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/22 09:59:52 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Сессия создана.
# Driver Memory Config: 4g
# Executor Memory Config: 4g
# 📊 Активных экзекуторов (проверка через RDD): 2
#
# 🖥️ Где выполнялись задачи:
# Executor ID: Driver/Local, PID: 63013
# Executor ID: Driver/Local, PID: 63012
# Executor ID: Driver/Local, PID: 62999
# Executor ID: Driver/Local, PID: 63000
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.246.67.107:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local-cluster[2, 6, 4096]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>LocalClusterTest</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Импорты (HypEx)

# %%
import csv
import random

import pandas as pd
import pyspark.pandas as ps

import warnings
from pyspark.pandas.utils import PandasAPIOnSparkAdviceWarning
warnings.filterwarnings("ignore", category=PandasAPIOnSparkAdviceWarning)
from hypex import AATest, ABTest
from hypex.analyzers.aa import AAScoreAnalyzer, OneAAStatAnalyzer
from hypex.comparators import StatsTTest, StatsChi2Test, GroupSizes, GroupTTest, GroupKSTest, GroupChi2Test, GroupDifference
from hypex.comparators.abstract import Comparator
from hypex.comparators.stats_hypothesis_testing import StatsTTest
from hypex.dataset import ExperimentData, AdditionalTreatmentRole
from hypex.dataset import ExperimentData, AdditionalTreatmentRole, TargetRole
from hypex.dataset import (Dataset, 
                           SmallDataset, 
                           InfoRole, 
                           TargetRole, 
                           TreatmentRole, 
                           DatasetAdapter, 
                           DefaultRole, 
                           StratificationRole)
from hypex.dataset.roles import TargetRole, FeatureRole, InfoRole, StatisticRole
from hypex.experiments.base import Experiment, OnRoleExperiment
from hypex.experiments.base_complex import ParamsExperiment
from hypex.reporters import DatasetReporter
from hypex.reporters.aa import OneAADictReporter
from hypex.splitters import AASplitter
from hypex.utils import BackendsEnum, SpaceEnum
from hypex.utils import SpaceEnum
from hypex.ui.aa import AAOutput
from hypex.ui.base import ExperimentShell

from hypex.experiments import IfParamsExperiment
# Out:
# /Users/danilsamsutdinov/HypEx/.venv/lib/python3.11/site-packages/pyspark/pandas/__init__.py:50: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(

# %% [markdown]
# ## Генерация тестовых данных

# %%
def generate_test_data(
    n_rows: int = 100,
    filename: str | None = None,
    return_df: bool = True
) -> pd.DataFrame | None:
    
    headers = ['user_id', 
               'signup_month', 
               'treat', 'pre_spends', 
               'post_spends', 'age', 'gender', 'industry']
    
    data = []
    current_id = 0
    
    while len(data) < n_rows:
        if current_id > 0 and current_id % 10 == 0:
            current_id += 1
            continue
            
        user_id = float(current_id)
        signup_month = float(random.randint(0, 11))
        treat = float(random.choice([0, 1]))
        
        pre_spends = random.uniform(450, 550)
        
        if treat == 0.0:
            post_spends = pre_spends * random.uniform(0.80, 0.90)
        else:
            post_spends = pre_spends * random.uniform(1.00, 1.10)
            
        age = float(random.randint(18, 70))
        gender = random.choice(['M', 'F'])
        industry = random.choice(['Logistics', 'E-commerce'])
        
        data.append([
            user_id, signup_month, treat, 
            round(pre_spends, 1), round(post_spends, 1), 
            age, gender, industry
        ])
        
        current_id += 1

    df = pd.DataFrame(data, columns=headers)
    
    if filename:
        df.to_csv(filename, index=False, encoding='utf-8')
    
    if return_df:
        return df

# %%
def create_spark_ds(n_rows: int = 100) -> Dataset:
    return Dataset(
        roles={
            "user_id": InfoRole(float),
            "treat": TreatmentRole(),
            "pre_spends": TargetRole(),
            "post_spends": DefaultRole(),
            "gender": StratificationRole(str),
            "industry" : DefaultRole()
        }, 
        data=generate_test_data(n_rows=n_rows), 
        session=sp_s,
        backend=BackendsEnum.spark
    )

# %% [markdown]
# ## Запуск AA-теста

# %%
ds = create_spark_ds(n_rows=1000)
ds.persist()
exp_data = ExperimentData(ds)
aa_test = AATest(n_iterations=10)
result = aa_test.execute(exp_data)
exp_data.analysis_tables
# Out:
# [DEBUG] Experiment.execute | transformer=False | id(data)=5135284688
# [DEBUG] Experiment.execute | запуск ParamsExperiment | id(data)=5135284688 | keys=[]
#   0%|          | 0/10 [00:00<?, ?it/s]
# [DEBUG] Experiment.execute | transformer=False | id(data)=5760457232
# [DEBUG] Experiment.execute | запуск AASplitter | id(data)=5760457232 | keys=[]
# executor.key = AASplitter┴rs 0┴; dt = 1.6035c
# [DEBUG] Experiment.execute | запуск Experiment | id(data)=5760457232 | keys=[]
# [DEBUG] Experiment.execute | transformer=False | id(data)=5760457232
# [DEBUG] Experiment.execute | запуск GroupSizes | id(data)=5760457232 | keys=[]
# executor.key = GroupSizes┴┴AASplitter|rs 0|; dt = 1.3398c
# [DEBUG] Experiment.execute | запуск OnRoleExperiment | id(data)=5760457232 | keys=['GroupSizes┴┴AASplitter|rs 0|']
# [DEBUG] Experiment.execute | transformer=False | id(data)=5760457232
# [DEBUG] Experiment.execute | запуск GroupDifference | id(data)=5760457232 | keys=['GroupSizes┴┴AASplitter|rs 0|']
# executor.key = GroupDifference┴┴pre_spends; dt = 1.6077c
# [DEBUG] Experiment.execute | запуск TTest | id(data)=5760457232 | keys=['GroupSizes┴┴AASplitter|rs 0|', 'GroupDifference┴┴pre_spends']
# executor.key = TTest┴┴; dt = 1.9132c
# [DEBUG] Experiment.execute | запуск Chi2Test | id(data)=5760457232 | keys=['GroupSizes┴┴AASplitter|rs 0|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
#  10%|█         | 1/10 [00:07<01:06,  7.40s/it]
# executor.key = Chi2Test┴┴; dt = 0.5127c
# executor.key = OnRoleExperiment┴┴; dt = 4.0400c
# [DEBUG] Experiment.execute | запуск OneAAStatAnalyzer | id(data)=5760457232 | keys=['GroupSizes┴┴AASplitter|rs 0|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
# executor.key = OneAAStatAnalyzer┴┴; dt = 0.0020c
# executor.key = Experiment┴┴; dt = 5.3819c
# [DEBUG] _extract_from_comparator | idx=0, col=test_0, val.type=SmallDataset, val=   control mean  test mean  difference  difference %
# 0      499.8306   501.9374      2.1068      0.421503
#
# 1 rows × 4 columns
# [DEBUG] _extract_from_comparator | idx=control, col=mean┆pre_spends, val.type=float, val=499.8306
# [DEBUG] _extract_from_comparator | idx=control, col=std┆pre_spends, val.type=float, val=28.816836463559554
# [DEBUG] _extract_from_comparator | idx=control, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0, col=mean┆pre_spends, val.type=float, val=501.93739999999997
# [DEBUG] _extract_from_comparator | idx=test_0, col=std┆pre_spends, val.type=float, val=29.062978075711
# [DEBUG] _extract_from_comparator | idx=test_0, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=p-value, val.type=float, val=0.24998947492545837
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=statistic, val.type=float, val=-1.1510448651121323
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=pass, val.type=float, val=0.0
# [DEBUG] Experiment.execute | transformer=False | id(data)=5764242320
# [DEBUG] Experiment.execute | запуск AASplitter | id(data)=5764242320 | keys=[]
# executor.key = AASplitter┴rs 1┴; dt = 0.7152c
# [DEBUG] Experiment.execute | запуск Experiment | id(data)=5764242320 | keys=[]
# [DEBUG] Experiment.execute | transformer=False | id(data)=5764242320
# [DEBUG] Experiment.execute | запуск GroupSizes | id(data)=5764242320 | keys=[]
# executor.key = GroupSizes┴┴AASplitter|rs 1|; dt = 0.9672c
# [DEBUG] Experiment.execute | запуск OnRoleExperiment | id(data)=5764242320 | keys=['GroupSizes┴┴AASplitter|rs 1|']
# [DEBUG] Experiment.execute | transformer=False | id(data)=5764242320
# [DEBUG] Experiment.execute | запуск GroupDifference | id(data)=5764242320 | keys=['GroupSizes┴┴AASplitter|rs 1|']
# executor.key = GroupDifference┴┴pre_spends; dt = 1.2222c
# [DEBUG] Experiment.execute | запуск TTest | id(data)=5764242320 | keys=['GroupSizes┴┴AASplitter|rs 1|', 'GroupDifference┴┴pre_spends']
# executor.key = TTest┴┴; dt = 1.5367c
# [DEBUG] Experiment.execute | запуск Chi2Test | id(data)=5764242320 | keys=['GroupSizes┴┴AASplitter|rs 1|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
#  20%|██        | 2/10 [00:12<00:48,  6.02s/it]
# executor.key = Chi2Test┴┴; dt = 0.4602c
# executor.key = OnRoleExperiment┴┴; dt = 3.2247c
# [DEBUG] Experiment.execute | запуск OneAAStatAnalyzer | id(data)=5764242320 | keys=['GroupSizes┴┴AASplitter|rs 1|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
# executor.key = OneAAStatAnalyzer┴┴; dt = 0.0016c
# executor.key = Experiment┴┴; dt = 4.1936c
# [DEBUG] _extract_from_comparator | idx=0, col=test_0, val.type=SmallDataset, val=   control mean  test mean  difference  difference %
# 0       501.925    499.843      -2.082     -0.414803
#
# 1 rows × 4 columns
# [DEBUG] _extract_from_comparator | idx=control, col=mean┆pre_spends, val.type=float, val=501.9250000000001
# [DEBUG] _extract_from_comparator | idx=control, col=std┆pre_spends, val.type=float, val=28.540564160597995
# [DEBUG] _extract_from_comparator | idx=control, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0, col=mean┆pre_spends, val.type=float, val=499.84300000000013
# [DEBUG] _extract_from_comparator | idx=test_0, col=std┆pre_spends, val.type=float, val=29.33521775958045
# [DEBUG] _extract_from_comparator | idx=test_0, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=p-value, val.type=float, val=0.25561162381985075
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=statistic, val.type=float, val=1.1374777767949469
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=pass, val.type=float, val=0.0
# [DEBUG] Experiment.execute | transformer=False | id(data)=5760480656
# [DEBUG] Experiment.execute | запуск AASplitter | id(data)=5760480656 | keys=[]
# executor.key = AASplitter┴rs 2┴; dt = 0.6767c
# [DEBUG] Experiment.execute | запуск Experiment | id(data)=5760480656 | keys=[]
# [DEBUG] Experiment.execute | transformer=False | id(data)=5760480656
# [DEBUG] Experiment.execute | запуск GroupSizes | id(data)=5760480656 | keys=[]
# executor.key = GroupSizes┴┴AASplitter|rs 2|; dt = 0.8981c
# [DEBUG] Experiment.execute | запуск OnRoleExperiment | id(data)=5760480656 | keys=['GroupSizes┴┴AASplitter|rs 2|']
# [DEBUG] Experiment.execute | transformer=False | id(data)=5760480656
# [DEBUG] Experiment.execute | запуск GroupDifference | id(data)=5760480656 | keys=['GroupSizes┴┴AASplitter|rs 2|']
# executor.key = GroupDifference┴┴pre_spends; dt = 1.1573c
# [DEBUG] Experiment.execute | запуск TTest | id(data)=5760480656 | keys=['GroupSizes┴┴AASplitter|rs 2|', 'GroupDifference┴┴pre_spends']
# executor.key = TTest┴┴; dt = 1.4570c
# [DEBUG] Experiment.execute | запуск Chi2Test | id(data)=5760480656 | keys=['GroupSizes┴┴AASplitter|rs 2|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
#  30%|███       | 3/10 [00:17<00:38,  5.44s/it]
# executor.key = Chi2Test┴┴; dt = 0.4530c
# executor.key = OnRoleExperiment┴┴; dt = 3.0724c
# [DEBUG] Experiment.execute | запуск OneAAStatAnalyzer | id(data)=5760480656 | keys=['GroupSizes┴┴AASplitter|rs 2|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
# executor.key = OneAAStatAnalyzer┴┴; dt = 0.0016c
# executor.key = Experiment┴┴; dt = 3.9723c
# [DEBUG] _extract_from_comparator | idx=0, col=test_0, val.type=SmallDataset, val=   control mean  test mean  difference  difference %
# 0      501.7096   500.0584     -1.6512     -0.329115
#
# 1 rows × 4 columns
# [DEBUG] _extract_from_comparator | idx=control, col=mean┆pre_spends, val.type=float, val=501.7096
# [DEBUG] _extract_from_comparator | idx=control, col=std┆pre_spends, val.type=float, val=28.88288125341719
# [DEBUG] _extract_from_comparator | idx=control, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0, col=mean┆pre_spends, val.type=float, val=500.0583999999999
# [DEBUG] _extract_from_comparator | idx=test_0, col=std┆pre_spends, val.type=float, val=29.0121305124899
# [DEBUG] _extract_from_comparator | idx=test_0, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=p-value, val.type=float, val=0.36732863063288657
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=statistic, val.type=float, val=0.9018980567182584
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=pass, val.type=float, val=0.0
# [DEBUG] Experiment.execute | transformer=False | id(data)=5760168464
# [DEBUG] Experiment.execute | запуск AASplitter | id(data)=5760168464 | keys=[]
# executor.key = AASplitter┴rs 3┴; dt = 0.6222c
# [DEBUG] Experiment.execute | запуск Experiment | id(data)=5760168464 | keys=[]
# [DEBUG] Experiment.execute | transformer=False | id(data)=5760168464
# [DEBUG] Experiment.execute | запуск GroupSizes | id(data)=5760168464 | keys=[]
# executor.key = GroupSizes┴┴AASplitter|rs 3|; dt = 0.8665c
# [DEBUG] Experiment.execute | запуск OnRoleExperiment | id(data)=5760168464 | keys=['GroupSizes┴┴AASplitter|rs 3|']
# [DEBUG] Experiment.execute | transformer=False | id(data)=5760168464
# [DEBUG] Experiment.execute | запуск GroupDifference | id(data)=5760168464 | keys=['GroupSizes┴┴AASplitter|rs 3|']
# executor.key = GroupDifference┴┴pre_spends; dt = 1.1102c
# [DEBUG] Experiment.execute | запуск TTest | id(data)=5760168464 | keys=['GroupSizes┴┴AASplitter|rs 3|', 'GroupDifference┴┴pre_spends']
# executor.key = TTest┴┴; dt = 1.4072c
# [DEBUG] Experiment.execute | запуск Chi2Test | id(data)=5760168464 | keys=['GroupSizes┴┴AASplitter|rs 3|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
#  40%|████      | 4/10 [00:21<00:30,  5.10s/it]
# executor.key = Chi2Test┴┴; dt = 0.4585c
# executor.key = OnRoleExperiment┴┴; dt = 2.9805c
# [DEBUG] Experiment.execute | запуск OneAAStatAnalyzer | id(data)=5760168464 | keys=['GroupSizes┴┴AASplitter|rs 3|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
# executor.key = OneAAStatAnalyzer┴┴; dt = 0.0014c
# executor.key = Experiment┴┴; dt = 3.8485c
# [DEBUG] _extract_from_comparator | idx=0, col=test_0, val.type=SmallDataset, val=   control mean  test mean  difference  difference %
# 0       501.452    500.316      -1.136     -0.226542
#
# 1 rows × 4 columns
# [DEBUG] _extract_from_comparator | idx=control, col=mean┆pre_spends, val.type=float, val=501.4519999999999
# [DEBUG] _extract_from_comparator | idx=control, col=std┆pre_spends, val.type=float, val=27.998972497608612
# [DEBUG] _extract_from_comparator | idx=control, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0, col=mean┆pre_spends, val.type=float, val=500.316
# [DEBUG] _extract_from_comparator | idx=test_0, col=std┆pre_spends, val.type=float, val=29.87811083408769
# [DEBUG] _extract_from_comparator | idx=test_0, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=p-value, val.type=float, val=0.5351632557458438
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=statistic, val.type=float, val=0.620358744168713
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=pass, val.type=float, val=0.0
# [DEBUG] Experiment.execute | transformer=False | id(data)=5764279952
# [DEBUG] Experiment.execute | запуск AASplitter | id(data)=5764279952 | keys=[]
# executor.key = AASplitter┴rs 4┴; dt = 0.6121c
# [DEBUG] Experiment.execute | запуск Experiment | id(data)=5764279952 | keys=[]
# [DEBUG] Experiment.execute | transformer=False | id(data)=5764279952
# [DEBUG] Experiment.execute | запуск GroupSizes | id(data)=5764279952 | keys=[]
# executor.key = GroupSizes┴┴AASplitter|rs 4|; dt = 0.8687c
# [DEBUG] Experiment.execute | запуск OnRoleExperiment | id(data)=5764279952 | keys=['GroupSizes┴┴AASplitter|rs 4|']
# [DEBUG] Experiment.execute | transformer=False | id(data)=5764279952
# [DEBUG] Experiment.execute | запуск GroupDifference | id(data)=5764279952 | keys=['GroupSizes┴┴AASplitter|rs 4|']
# executor.key = GroupDifference┴┴pre_spends; dt = 1.0552c
# [DEBUG] Experiment.execute | запуск TTest | id(data)=5764279952 | keys=['GroupSizes┴┴AASplitter|rs 4|', 'GroupDifference┴┴pre_spends']
# executor.key = TTest┴┴; dt = 1.4263c
# [DEBUG] Experiment.execute | запуск Chi2Test | id(data)=5764279952 | keys=['GroupSizes┴┴AASplitter|rs 4|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
#  50%|█████     | 5/10 [00:26<00:24,  4.89s/it]
# executor.key = Chi2Test┴┴; dt = 0.4613c
# executor.key = OnRoleExperiment┴┴; dt = 2.9476c
# [DEBUG] Experiment.execute | запуск OneAAStatAnalyzer | id(data)=5764279952 | keys=['GroupSizes┴┴AASplitter|rs 4|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
# executor.key = OneAAStatAnalyzer┴┴; dt = 0.0015c
# executor.key = Experiment┴┴; dt = 3.8179c
# [DEBUG] _extract_from_comparator | idx=0, col=test_0, val.type=SmallDataset, val=   control mean  test mean  difference  difference %
# 0      501.5624   500.2056     -1.3568     -0.270515
#
# 1 rows × 4 columns
# [DEBUG] _extract_from_comparator | idx=control, col=mean┆pre_spends, val.type=float, val=501.56239999999985
# [DEBUG] _extract_from_comparator | idx=control, col=std┆pre_spends, val.type=float, val=28.676656840278145
# [DEBUG] _extract_from_comparator | idx=control, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0, col=mean┆pre_spends, val.type=float, val=500.20559999999944
# [DEBUG] _extract_from_comparator | idx=test_0, col=std┆pre_spends, val.type=float, val=29.22357890073586
# [DEBUG] _extract_from_comparator | idx=test_0, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=p-value, val.type=float, val=0.45886990121425186
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=statistic, val.type=float, val=0.7409964522903201
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=pass, val.type=float, val=0.0
# [DEBUG] Experiment.execute | transformer=False | id(data)=5764406160
# [DEBUG] Experiment.execute | запуск AASplitter | id(data)=5764406160 | keys=[]
# executor.key = AASplitter┴rs 5┴; dt = 0.5879c
# [DEBUG] Experiment.execute | запуск Experiment | id(data)=5764406160 | keys=[]
# [DEBUG] Experiment.execute | transformer=False | id(data)=5764406160
# [DEBUG] Experiment.execute | запуск GroupSizes | id(data)=5764406160 | keys=[]
# executor.key = GroupSizes┴┴AASplitter|rs 5|; dt = 0.8488c
# [DEBUG] Experiment.execute | запуск OnRoleExperiment | id(data)=5764406160 | keys=['GroupSizes┴┴AASplitter|rs 5|']
# [DEBUG] Experiment.execute | transformer=False | id(data)=5764406160
# [DEBUG] Experiment.execute | запуск GroupDifference | id(data)=5764406160 | keys=['GroupSizes┴┴AASplitter|rs 5|']
# executor.key = GroupDifference┴┴pre_spends; dt = 1.0809c
# [DEBUG] Experiment.execute | запуск TTest | id(data)=5764406160 | keys=['GroupSizes┴┴AASplitter|rs 5|', 'GroupDifference┴┴pre_spends']
# executor.key = TTest┴┴; dt = 1.3548c
# [DEBUG] Experiment.execute | запуск Chi2Test | id(data)=5764406160 | keys=['GroupSizes┴┴AASplitter|rs 5|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
#  60%|██████    | 6/10 [00:30<00:18,  4.72s/it]
# executor.key = Chi2Test┴┴; dt = 0.4075c
# executor.key = OnRoleExperiment┴┴; dt = 2.8476c
# [DEBUG] Experiment.execute | запуск OneAAStatAnalyzer | id(data)=5764406160 | keys=['GroupSizes┴┴AASplitter|rs 5|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
# executor.key = OneAAStatAnalyzer┴┴; dt = 0.0016c
# executor.key = Experiment┴┴; dt = 3.6980c
# [DEBUG] _extract_from_comparator | idx=0, col=test_0, val.type=SmallDataset, val=   control mean  test mean  difference  difference %
# 0      500.5306   501.2374      0.7068       0.14121
#
# 1 rows × 4 columns
# [DEBUG] _extract_from_comparator | idx=control, col=mean┆pre_spends, val.type=float, val=500.5306
# [DEBUG] _extract_from_comparator | idx=control, col=std┆pre_spends, val.type=float, val=29.06787585037658
# [DEBUG] _extract_from_comparator | idx=control, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0, col=mean┆pre_spends, val.type=float, val=501.23740000000004
# [DEBUG] _extract_from_comparator | idx=test_0, col=std┆pre_spends, val.type=float, val=28.846123116941655
# [DEBUG] _extract_from_comparator | idx=test_0, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=p-value, val.type=float, val=0.6996299334613681
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=statistic, val.type=float, val=-0.38593112297250337
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=pass, val.type=float, val=0.0
# [DEBUG] Experiment.execute | transformer=False | id(data)=5760149200
# [DEBUG] Experiment.execute | запуск AASplitter | id(data)=5760149200 | keys=[]
# executor.key = AASplitter┴rs 6┴; dt = 0.6000c
# [DEBUG] Experiment.execute | запуск Experiment | id(data)=5760149200 | keys=[]
# [DEBUG] Experiment.execute | transformer=False | id(data)=5760149200
# [DEBUG] Experiment.execute | запуск GroupSizes | id(data)=5760149200 | keys=[]
# executor.key = GroupSizes┴┴AASplitter|rs 6|; dt = 0.7982c
# [DEBUG] Experiment.execute | запуск OnRoleExperiment | id(data)=5760149200 | keys=['GroupSizes┴┴AASplitter|rs 6|']
# [DEBUG] Experiment.execute | transformer=False | id(data)=5760149200
# [DEBUG] Experiment.execute | запуск GroupDifference | id(data)=5760149200 | keys=['GroupSizes┴┴AASplitter|rs 6|']
# executor.key = GroupDifference┴┴pre_spends; dt = 1.0658c
# [DEBUG] Experiment.execute | запуск TTest | id(data)=5760149200 | keys=['GroupSizes┴┴AASplitter|rs 6|', 'GroupDifference┴┴pre_spends']
# executor.key = TTest┴┴; dt = 1.3947c
# [DEBUG] Experiment.execute | запуск Chi2Test | id(data)=5760149200 | keys=['GroupSizes┴┴AASplitter|rs 6|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
#  70%|███████   | 7/10 [00:35<00:13,  4.60s/it]
# executor.key = Chi2Test┴┴; dt = 0.4062c
# executor.key = OnRoleExperiment┴┴; dt = 2.8716c
# [DEBUG] Experiment.execute | запуск OneAAStatAnalyzer | id(data)=5760149200 | keys=['GroupSizes┴┴AASplitter|rs 6|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
# executor.key = OneAAStatAnalyzer┴┴; dt = 0.0015c
# executor.key = Experiment┴┴; dt = 3.6714c
# [DEBUG] _extract_from_comparator | idx=0, col=test_0, val.type=SmallDataset, val=   control mean  test mean  difference  difference %
# 0      501.0188   500.7492     -0.2696      -0.05381
#
# 1 rows × 4 columns
# [DEBUG] _extract_from_comparator | idx=control, col=mean┆pre_spends, val.type=float, val=501.01879999999994
# [DEBUG] _extract_from_comparator | idx=control, col=std┆pre_spends, val.type=float, val=29.144731897114948
# [DEBUG] _extract_from_comparator | idx=control, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0, col=mean┆pre_spends, val.type=float, val=500.74920000000003
# [DEBUG] _extract_from_comparator | idx=test_0, col=std┆pre_spends, val.type=float, val=28.77218616569667
# [DEBUG] _extract_from_comparator | idx=test_0, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=p-value, val.type=float, val=0.883004519989533
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=statistic, val.type=float, val=0.14719920339281073
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=pass, val.type=float, val=0.0
# [DEBUG] Experiment.execute | transformer=False | id(data)=5766180688
# [DEBUG] Experiment.execute | запуск AASplitter | id(data)=5766180688 | keys=[]
# executor.key = AASplitter┴rs 7┴; dt = 0.6195c
# [DEBUG] Experiment.execute | запуск Experiment | id(data)=5766180688 | keys=[]
# [DEBUG] Experiment.execute | transformer=False | id(data)=5766180688
# [DEBUG] Experiment.execute | запуск GroupSizes | id(data)=5766180688 | keys=[]
# executor.key = GroupSizes┴┴AASplitter|rs 7|; dt = 0.8407c
# [DEBUG] Experiment.execute | запуск OnRoleExperiment | id(data)=5766180688 | keys=['GroupSizes┴┴AASplitter|rs 7|']
# [DEBUG] Experiment.execute | transformer=False | id(data)=5766180688
# [DEBUG] Experiment.execute | запуск GroupDifference | id(data)=5766180688 | keys=['GroupSizes┴┴AASplitter|rs 7|']
# executor.key = GroupDifference┴┴pre_spends; dt = 1.0323c
# [DEBUG] Experiment.execute | запуск TTest | id(data)=5766180688 | keys=['GroupSizes┴┴AASplitter|rs 7|', 'GroupDifference┴┴pre_spends']
# executor.key = TTest┴┴; dt = 1.3200c
# [DEBUG] Experiment.execute | запуск Chi2Test | id(data)=5766180688 | keys=['GroupSizes┴┴AASplitter|rs 7|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
#  80%|████████  | 8/10 [00:39<00:09,  4.51s/it]
# executor.key = Chi2Test┴┴; dt = 0.4174c
# executor.key = OnRoleExperiment┴┴; dt = 2.7748c
# [DEBUG] Experiment.execute | запуск OneAAStatAnalyzer | id(data)=5766180688 | keys=['GroupSizes┴┴AASplitter|rs 7|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
# executor.key = OneAAStatAnalyzer┴┴; dt = 0.0017c
# executor.key = Experiment┴┴; dt = 3.6173c
# [DEBUG] _extract_from_comparator | idx=0, col=test_0, val.type=SmallDataset, val=   control mean  test mean  difference  difference %
# 0      500.2136   501.5544      1.3408      0.268045
#
# 1 rows × 4 columns
# [DEBUG] _extract_from_comparator | idx=control, col=mean┆pre_spends, val.type=float, val=500.21360000000004
# [DEBUG] _extract_from_comparator | idx=control, col=std┆pre_spends, val.type=float, val=29.272273348922326
# [DEBUG] _extract_from_comparator | idx=control, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0, col=mean┆pre_spends, val.type=float, val=501.55440000000004
# [DEBUG] _extract_from_comparator | idx=test_0, col=std┆pre_spends, val.type=float, val=28.627326950602164
# [DEBUG] _extract_from_comparator | idx=test_0, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=p-value, val.type=float, val=0.46418574135426494
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=statistic, val.type=float, val=-0.7322535637995126
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=pass, val.type=float, val=0.0
# [DEBUG] Experiment.execute | transformer=False | id(data)=5766573904
# [DEBUG] Experiment.execute | запуск AASplitter | id(data)=5766573904 | keys=[]
# executor.key = AASplitter┴rs 8┴; dt = 0.5787c
# [DEBUG] Experiment.execute | запуск Experiment | id(data)=5766573904 | keys=[]
# [DEBUG] Experiment.execute | transformer=False | id(data)=5766573904
# [DEBUG] Experiment.execute | запуск GroupSizes | id(data)=5766573904 | keys=[]
# executor.key = GroupSizes┴┴AASplitter|rs 8|; dt = 0.8186c
# [DEBUG] Experiment.execute | запуск OnRoleExperiment | id(data)=5766573904 | keys=['GroupSizes┴┴AASplitter|rs 8|']
# [DEBUG] Experiment.execute | transformer=False | id(data)=5766573904
# [DEBUG] Experiment.execute | запуск GroupDifference | id(data)=5766573904 | keys=['GroupSizes┴┴AASplitter|rs 8|']
# executor.key = GroupDifference┴┴pre_spends; dt = 1.0379c
# [DEBUG] Experiment.execute | запуск TTest | id(data)=5766573904 | keys=['GroupSizes┴┴AASplitter|rs 8|', 'GroupDifference┴┴pre_spends']
# executor.key = TTest┴┴; dt = 1.3628c
# [DEBUG] Experiment.execute | запуск Chi2Test | id(data)=5766573904 | keys=['GroupSizes┴┴AASplitter|rs 8|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
#  90%|█████████ | 9/10 [00:43<00:04,  4.46s/it]
# executor.key = Chi2Test┴┴; dt = 0.4374c
# executor.key = OnRoleExperiment┴┴; dt = 2.8422c
# [DEBUG] Experiment.execute | запуск OneAAStatAnalyzer | id(data)=5766573904 | keys=['GroupSizes┴┴AASplitter|rs 8|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
# executor.key = OneAAStatAnalyzer┴┴; dt = 0.0015c
# executor.key = Experiment┴┴; dt = 3.6625c
# [DEBUG] _extract_from_comparator | idx=0, col=test_0, val.type=SmallDataset, val=   control mean  test mean  difference  difference %
# 0      499.5552   502.2128      2.6576      0.531993
#
# 1 rows × 4 columns
# [DEBUG] _extract_from_comparator | idx=control, col=mean┆pre_spends, val.type=float, val=499.55519999999996
# [DEBUG] _extract_from_comparator | idx=control, col=std┆pre_spends, val.type=float, val=28.538671035086704
# [DEBUG] _extract_from_comparator | idx=control, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0, col=mean┆pre_spends, val.type=float, val=502.2128000000005
# [DEBUG] _extract_from_comparator | idx=test_0, col=std┆pre_spends, val.type=float, val=29.31375562252976
# [DEBUG] _extract_from_comparator | idx=test_0, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=p-value, val.type=float, val=0.1466649423843306
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=statistic, val.type=float, val=-1.4525432117246313
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=pass, val.type=float, val=0.0
# [DEBUG] Experiment.execute | transformer=False | id(data)=5765845072
# [DEBUG] Experiment.execute | запуск AASplitter | id(data)=5765845072 | keys=[]
# executor.key = AASplitter┴rs 9┴; dt = 0.5995c
# [DEBUG] Experiment.execute | запуск Experiment | id(data)=5765845072 | keys=[]
# [DEBUG] Experiment.execute | transformer=False | id(data)=5765845072
# [DEBUG] Experiment.execute | запуск GroupSizes | id(data)=5765845072 | keys=[]
# executor.key = GroupSizes┴┴AASplitter|rs 9|; dt = 0.7812c
# [DEBUG] Experiment.execute | запуск OnRoleExperiment | id(data)=5765845072 | keys=['GroupSizes┴┴AASplitter|rs 9|']
# [DEBUG] Experiment.execute | transformer=False | id(data)=5765845072
# [DEBUG] Experiment.execute | запуск GroupDifference | id(data)=5765845072 | keys=['GroupSizes┴┴AASplitter|rs 9|']
# executor.key = GroupDifference┴┴pre_spends; dt = 1.0111c
# [DEBUG] Experiment.execute | запуск TTest | id(data)=5765845072 | keys=['GroupSizes┴┴AASplitter|rs 9|', 'GroupDifference┴┴pre_spends']
# executor.key = TTest┴┴; dt = 1.3192c
# [DEBUG] Experiment.execute | запуск Chi2Test | id(data)=5765845072 | keys=['GroupSizes┴┴AASplitter|rs 9|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
# 100%|██████████| 10/10 [00:47<00:00,  4.79s/it]
# executor.key = Chi2Test┴┴; dt = 0.4179c
# executor.key = OnRoleExperiment┴┴; dt = 2.7529c
# [DEBUG] Experiment.execute | запуск OneAAStatAnalyzer | id(data)=5765845072 | keys=['GroupSizes┴┴AASplitter|rs 9|', 'GroupDifference┴┴pre_spends', 'StatsTTest┴┴pre_spends┆stats', 'StatsTTest┴┴pre_spends']
# executor.key = OneAAStatAnalyzer┴┴; dt = 0.0017c
# executor.key = Experiment┴┴; dt = 3.5360c
# [DEBUG] _extract_from_comparator | idx=0, col=test_0, val.type=SmallDataset, val=   control mean  test mean  difference  difference %
# 0      500.5644   501.2036      0.6392      0.127696
#
# 1 rows × 4 columns
# [DEBUG] _extract_from_comparator | idx=control, col=mean┆pre_spends, val.type=float, val=500.5644000000001
# [DEBUG] _extract_from_comparator | idx=control, col=std┆pre_spends, val.type=float, val=29.562919088107993
# [DEBUG] _extract_from_comparator | idx=control, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0, col=mean┆pre_spends, val.type=float, val=501.20359999999994
# [DEBUG] _extract_from_comparator | idx=test_0, col=std┆pre_spends, val.type=float, val=28.339365312098735
# [DEBUG] _extract_from_comparator | idx=test_0, col=count┆pre_spends, val.type=float, val=500.0
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=p-value, val.type=float, val=0.7271516493024583
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=statistic, val.type=float, val=-0.34901502702043774
# [DEBUG] _extract_from_comparator | idx=test_0┆pre_spends, col=pass, val.type=float, val=0.0
# [DEBUG] _set_result | self.id=ParamsExperiment┴┴AATest | len(results)=10
# [DEBUG] _set_result DIRECT | id=5135284688 | keys=['ParamsExperiment┴┴AATest']
# [DEBUG] ParamsExperiment.execute | возвращаем id=5135284688 | keys=['ParamsExperiment┴┴AATest']
# executor.key = ParamsExperiment┴┴AATest; dt = 47.9457c
# [DEBUG] Experiment.execute | запуск AAScoreAnalyzer | id(data)=5135284688 | keys=['ParamsExperiment┴┴AATest']
# [DEBUG] AAScoreAnalyzer | id=5135284688 keys=['ParamsExperiment┴┴AATest']
# [DEBUG] AAScoreAnalyzer | All keys in analysis_tables: ['ParamsExperiment┴┴AATest']
# best_index = 12
# executor.key = AAScoreAnalyzer┴┴best splitter; dt = 0.2913c
# {'ParamsExperiment┴┴AATest':         feature              group StatsTTest pass StatsTTest p-value
#  0    pre_spends  test_0┆pre_spends          NOT OK           0.249989
#  1          mean                all          NOT OK           0.249989
#  2    pre_spends  test_0┆pre_spends          NOT OK           0.255612
#  3          mean                all          NOT OK           0.255612
#  4    pre_spends  test_0┆pre_spends          NOT OK           0.367329
#  ...         ...                ...             ...                ...
#  15         mean                all          NOT OK           0.464186
#  16   pre_spends  test_0┆pre_spends          NOT OK           0.146665
#  17         mean                all          NOT OK           0.146665
#  18   pre_spends  test_0┆pre_spends          NOT OK           0.727152
#  19         mean                all          NOT OK           0.727152
#
#  20 rows × 4 columns,
#  'AAScoreAnalyzer┴┴aa score':    StatsTTest score  StatsTTest pass
#  0              0.95             True
#
#  1 rows × 2 columns,
#  'AAScoreAnalyzer┴┴best split statistics':        feature              group StatsTTest pass  StatsTTest p-value
#  12  pre_spends  test_0┆pre_spends          NOT OK            0.883005
#
#  1 rows × 4 columns}

# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import psutil
import os
import gc
from datetime import datetime

# %%
# ================= КОНФИГУРАЦИЯ =================
class BenchmarkConfig:
    # N_ROWS_VALUES = [1000, 5000, 10000, 50000, 100000, 500000, 1000000, 5000000, 10000000][::-1]
    N_ROWS_VALUES = [1000, 5000, 10000, 50000, 100000]

    N_REPEATS = 1
    MEMORY_SAMPLE_INTERVAL = 0.5  # сек
    SAVE_PATH = 'spark_benchmark_results'
    
    @classmethod
    def ensure_dir(cls):
        os.makedirs(cls.SAVE_PATH, exist_ok=True)

# %%
# ================= МОНТОРИНГ ПАМЯТИ =================
class MemoryMonitor:
    """Сборщик метрик памяти (JVM + System + Spark)"""
    
    def __init__(self, spark_session):
        self.spark = spark_session
        self.jvm = spark_session._jvm
        self.process = psutil.Process(os.getpid())
        self.samples = []
        self.is_monitoring = False
        
    def start(self):
        self.samples = []
        self.is_monitoring = True
        
    def stop(self):
        self.is_monitoring = False
        
    def sample(self):
        """Снимает текущий срез метрик памяти"""
        if not self.is_monitoring:
            return
            
        try:
            runtime = self.jvm.Runtime.getRuntime()
            
            sample = {
                'timestamp': time.time(),
                # JVM Heap
                'jvm_heap_used_mb': (runtime.totalMemory() - runtime.freeMemory()) / 1024 / 1024,
                'jvm_heap_max_mb': runtime.maxMemory() / 1024 / 1024,
                'jvm_heap_committed_mb': runtime.totalMemory() / 1024 / 1024,
                
                # System RSS
                'process_rss_mb': self.process.memory_info().rss / 1024 / 1024,
                'process_vms_mb': self.process.memory_info().vms / 1024 / 1024,
                
                # CPU
                'cpu_percent': self.process.cpu_percent(interval=0.1),
            }
            
            # Spark-метрики (если доступны)
            try:
                sc = self.spark.sparkContext
                if hasattr(sc, '_jsc'):
                    jsc = sc._jsc
                    # Статистика пула (упрощенно)
                    sample['spark_executors'] = len(sc._jsc.sc().executorIds())
            except:
                sample['spark_executors'] = 0
                
            self.samples.append(sample)
            
        except Exception as e:
            print(f"⚠️ Ошибка сбора метрик: {e}")
    
    def get_statistics(self):
        """Агрегирует статистику по собранным сэмплам"""
        if not self.samples:
            return {}
            
        df = pd.DataFrame(self.samples)
        
        stats = {
            'jvm_heap_used_avg_mb': df['jvm_heap_used_mb'].mean(),
            'jvm_heap_used_max_mb': df['jvm_heap_used_mb'].max(),
            'jvm_heap_used_min_mb': df['jvm_heap_used_mb'].min(),
            'process_rss_avg_mb': df['process_rss_mb'].mean(),
            'process_rss_max_mb': df['process_rss_mb'].max(),
            'cpu_avg_percent': df['cpu_percent'].mean(),
            'cpu_max_percent': df['cpu_percent'].max(),
            'samples_count': len(df),
        }
        return stats
    
    def plot_memory_timeline(self, ax):
        """Рисует таймлайн потребления памяти"""
        if not self.samples:
            return
            
        df = pd.DataFrame(self.samples)
        df['relative_time'] = df['timestamp'] - df['timestamp'].min()
        
        ax.plot(df['relative_time'], df['jvm_heap_used_mb'], label='JVM Heap Used', color='red', linewidth=2)
        ax.plot(df['relative_time'], df['process_rss_mb'], label='Process RSS', color='blue', linewidth=2)
        ax.axhline(y=df['jvm_heap_max_mb'].iloc[0], color='red', linestyle='--', alpha=0.5, label='JVM Max')
        
        ax.set_xlabel('Время (сек)')
        ax.set_ylabel('Память (MB)')
        ax.set_title('Динамика потребления памяти')
        ax.legend(loc='upper left')
        ax.grid(True, alpha=0.3)

# %%
# ================= ФОНОВЫЙ СБОРЩИК =================
class BackgroundMonitor:
    """Запускает сбор метрик в фоновом потоке"""
    
    def __init__(self, memory_monitor, interval=0.5):
        self.monitor = memory_monitor
        self.interval = interval
        self.running = False
        
    def start(self):
        self.running = True
        self.monitor.start()
        
    def stop(self):
        self.running = False
        self.monitor.stop()
        
    def run_and_collect(self, func, *args, **kwargs):
        """Запускает функцию и параллельно собирает метрики"""
        import threading
        
        def collect_loop():
            while self.running:
                self.monitor.sample()
                time.sleep(self.interval)
        
        # Запуск потока сбора
        collector = threading.Thread(target=collect_loop, daemon=True)
        self.start()
        collector.start()
        
        # Выполнение целевой функции
        result = func(*args, **kwargs)
        
        # Остановка
        self.stop()
        collector.join(timeout=1)
        
        return result, self.monitor.get_statistics()

# %%
# ================= БЕНЧМАРК =================
def run_single_test(spark_ds, spark_session, monitor):
    """Выполняет один тестовый прогон"""
    exp_data = ExperimentData(spark_ds)
    AATest_without_analyse().execute(exp_data)

# %%
def run_benchmark_with_memory(spark_session):
    """Полный бенчмарк с памятью"""
    BenchmarkConfig.ensure_dir()
    monitor = MemoryMonitor(spark_session)
    bg_monitor = BackgroundMonitor(monitor, interval=BenchmarkConfig.MEMORY_SAMPLE_INTERVAL)
    
    results = []
    print(f"🚀 Старт бенчмарка: {datetime.now().strftime('%H:%M:%S')}")
    print(f"💾 JVM Max Heap: {spark_session._jvm.Runtime.getRuntime().maxMemory() / 1024 / 1024 / 1024:.2f} GB")
    print("-" * 70)
    
    for n_rows in BenchmarkConfig.N_ROWS_VALUES:
        spark_ds = create_spark_ds(n_rows=n_rows)
        print(f"\n📊 n_rows = {n_rows:,}")
        
        gc.collect()
        time.sleep(0.5)
        
        times = []
        memory_stats_list = []
        
        for i in range(BenchmarkConfig.N_REPEATS):
            try:
                start = time.perf_counter()
                
                _, mem_stats = bg_monitor.run_and_collect(
                    run_single_test, spark_ds, spark_session, monitor
                )
                
                end = time.perf_counter()
                duration = end - start
                times.append(duration)
                memory_stats_list.append(mem_stats)
                
                print(f"   Повтор {i+1}: {duration:.3f} сек | "
                      f"RSS Max: {mem_stats.get('process_rss_max_mb', 0):.0f} MB")
                
            except Exception as e:
                print(f"   ❌ Ошибка: {e}")
                times.append(None)
                memory_stats_list.append({})
        
        valid_times = [t for t in times if t is not None]
        if valid_times:
            avg_mem_stats = {
                k: np.mean([s.get(k, 0) for s in memory_stats_list]) 
                for k in memory_stats_list[0].keys() if k != 'samples_count'
            }
            max_mem_stats = {
                k: np.max([s.get(k, 0) for s in memory_stats_list]) 
                for k in memory_stats_list[0].keys() if k != 'samples_count'
            }
            
            # === ИСПРАВЛЕНИЕ: Считаем mb_per_million сразу здесь ===
            rss_max = max_mem_stats.get('process_rss_max_mb', 0)
            mb_per_million = (rss_max / n_rows * 1_000_000) if n_rows > 0 else 0
            
            results.append({
                'n_rows': n_rows,
                'time_mean_sec': np.mean(valid_times),
                'time_std_sec': np.std(valid_times),
                'jvm_heap_avg_mb': avg_mem_stats.get('jvm_heap_used_avg_mb', 0),
                'jvm_heap_max_mb': max_mem_stats.get('jvm_heap_used_max_mb', 0),
                'process_rss_avg_mb': avg_mem_stats.get('process_rss_avg_mb', 0),
                'process_rss_max_mb': rss_max,
                'cpu_avg_percent': avg_mem_stats.get('cpu_avg_percent', 0),
                'rows_per_sec': n_rows / np.mean(valid_times),
                'mb_per_million': mb_per_million,  # Добавлено в результат
            })
        else:
            results.append({'n_rows': n_rows, 'time_mean_sec': None})
    
    print(f"\n🏁 Завершено: {datetime.now().strftime('%H:%M:%S')}")
    return pd.DataFrame(results)

# %%
# ================= ВИЗУАЛИЗАЦИЯ =================
def plot_comprehensive_results(df):
    """Строит расширенные графики"""
    df_clean = df.dropna(subset=['time_mean_sec']).copy()
    if len(df_clean) == 0:
        print("⚠️ Нет данных для графиков")
        return

    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle('📈 Комплексный анализ производительности и памяти', fontsize=14, fontweight='bold')
    
    # 1. Время выполнения
    ax1 = axes[0, 0]
    ax1.errorbar(df_clean['n_rows'], df_clean['time_mean_sec'], 
                 yerr=df_clean['time_std_sec'], marker='o', capsize=5)
    ax1.set_xscale('log')
    ax1.set_xlabel('n_rows')
    ax1.set_ylabel('Время (сек)')
    ax1.set_title('Время выполнения')
    ax1.grid(True, alpha=0.3)
    
    # 2. JVM Память
    ax2 = axes[0, 1]
    ax2.plot(df_clean['n_rows'], df_clean['jvm_heap_avg_mb'], marker='s', label='Avg', color='red')
    ax2.plot(df_clean['n_rows'], df_clean['jvm_heap_max_mb'], marker='^', label='Max', color='darkred')
    ax2.set_xscale('log')
    ax2.set_xlabel('n_rows')
    ax2.set_ylabel('Память (MB)')
    ax2.set_title('Потребление JVM Heap')
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    
    # 3. Системная память (RSS)
    ax3 = axes[0, 2]
    ax3.plot(df_clean['n_rows'], df_clean['process_rss_avg_mb'], marker='d', label='RSS Avg', color='blue')
    ax3.plot(df_clean['n_rows'], df_clean['process_rss_max_mb'], marker='x', label='RSS Max', color='navy')
    ax3.set_xscale('log')
    ax3.set_xlabel('n_rows')
    ax3.set_ylabel('Память (MB)')
    ax3.set_title('Системная память процесса')
    ax3.legend()
    ax3.grid(True, alpha=0.3)
    
    # 4. Производительность
    ax4 = axes[1, 0]
    ax4.plot(df_clean['n_rows'], df_clean['rows_per_sec'], marker='o', color='green')
    ax4.set_xscale('log')
    ax4.set_xlabel('n_rows')
    ax4.set_ylabel('строк/сек')
    ax4.set_title('Пропускная способность')
    ax4.grid(True, alpha=0.3)
    
    # 5. Память на 1 млн строк (эффективность)
    ax5 = axes[1, 1]
    # Проверка на наличие колонки на случай загрузки старого CSV
    if 'mb_per_million' in df_clean.columns:
        data_to_plot = df_clean['mb_per_million']
    else:
        # Фолбэк если колонки нет (пересчет)
        data_to_plot = df_clean['process_rss_max_mb'] / df_clean['n_rows'] * 1_000_000
        
    ax5.bar(range(len(df_clean)), data_to_plot, color='orange')
    ax5.set_xticks(range(len(df_clean)))
    ax5.set_xticklabels([f"{n/1e6:.1f}M" for n in df_clean['n_rows']], rotation=45)
    ax5.set_ylabel('MB на 1 млн строк')
    ax5.set_title('Эффективность использования памяти')
    ax5.grid(True, alpha=0.3, axis='y')
    
    # 6. CPU загрузка
    ax6 = axes[1, 2]
    ax6.plot(df_clean['n_rows'], df_clean['cpu_avg_percent'], marker='*', color='purple')
    ax6.set_xscale('log')
    ax6.set_xlabel('n_rows')
    ax6.set_ylabel('CPU %')
    ax6.set_title('Загрузка CPU')
    ax6.set_ylim(0, 100)
    ax6.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f'{BenchmarkConfig.SAVE_PATH}/full_analysis.png', dpi=300, bbox_inches='tight')
    print(f"📁 Графики сохранены в {BenchmarkConfig.SAVE_PATH}/full_analysis.png")
    plt.show()

# %%
def print_memory_analysis(df):
    """Выводит текстовый анализ памяти"""
    df_clean = df.dropna(subset=['time_mean_sec']).copy()
    if len(df_clean) < 2:
        print("⚠️ Недостаточно данных для анализа памяти")
        return

    print("\n" + "="*70)
    print("🔍 АНАЛИЗ ПОТРЕБЛЕНИЯ ПАМЯТИ")
    print("="*70)
    
    first, last = df_clean.iloc[0], df_clean.iloc[-1]
    
    # Рост памяти
    mem_growth = last['process_rss_max_mb'] / first['process_rss_max_mb'] if first['process_rss_max_mb'] > 0 else 0
    data_growth = last['n_rows'] / first['n_rows']
    
    print(f"\n📏 Масштабирование памяти:")
    print(f"   Данные: ×{data_growth:,.1f}")
    print(f"   Память (RSS): ×{mem_growth:.2f}")
    
    if mem_growth > data_growth * 1.5:
        print("   ⚠️ Память растет быстрее данных! Возможна утечка или неоптимальные структуры.")
    else:
        print("   ✓ Память масштабируется линейно или лучше.")
    
    # Пики потребления
    print(f"\n📊 Пиковые значения:")
    print(f"   Max JVM Heap: {df_clean['jvm_heap_max_mb'].max():.0f} MB "
          f"({df_clean['jvm_heap_max_mb'].max()/1024:.2f} GB)")
    print(f"   Max Process RSS: {df_clean['process_rss_max_mb'].max():.0f} MB "
          f"({df_clean['process_rss_max_mb'].max()/1024:.2f} GB)")
    
    # Эффективность (с проверкой существования колонки)
    if 'mb_per_million' in df_clean.columns:
        avg_mb_per_million = df_clean['mb_per_million'].mean()
    else:
        # Пересчет если колонки нет
        avg_mb_per_million = (df_clean['process_rss_max_mb'] / df_clean['n_rows'] * 1_000_000).mean()
        
    print(f"\n⚡ Эффективность:")
    print(f"   Среднее потребление: {avg_mb_per_million:.2f} MB на 1 млн строк")
    
    # Рекомендации
    print(f"\n💡 Рекомендации по памяти:")
    max_rss_gb = df_clean['process_rss_max_mb'].max() / 1024
    if max_rss_gb > 8:
        print(f"   • Высокое потребление ({max_rss_gb:.1f} GB). Увеличьте `spark.driver.memory`.")
    if 'cpu_avg_percent' in df_clean.columns and df_clean['cpu_avg_percent'].mean() < 50:
        print(f"   • Низкая загрузка CPU. Можно увеличить параллелизм.")

# %%
# 2. Запуск бенчмарка
results_df = run_benchmark_with_memory(sp_s)

# 3. Сохранение данных
results_df.to_csv(f'{BenchmarkConfig.SAVE_PATH}/benchmark_data.csv', index=False)

# %%
# 4. Визуализация и анализ
plot_comprehensive_results(results_df.sort_values(by="n_rows"))
print_memory_analysis(results_df.sort_values(by="n_rows"))

# %%
f'{BenchmarkConfig.SAVE_PATH}/benchmark_data.csv'
